# %%
import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import specgram
import soundfile as sf
import sys


np.random.seed(1337)
from tensorflow import set_random_seed
set_random_seed(1337)

from utils import *
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 328587773893093789
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7923105792
# locality {
#   bus_id: 1
# }
# incarnation: 12366471706970894481
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 7950250804
# locality {
#   bus_id: 1
# }
# incarnation: 2699331639785157729
# physical_device_desc: "device: 1, name: GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1"
# ]

# %%
project_dir = '/home/rabreu/projeto_multimodal/'
data_dir = project_dir+'data/'

audioset_indices_csv = project_dir+'segments/subset_class_labels_indices.csv'

## pegando dataset desbalanceado, que eu balanceei para 600 ocorrências para cada classe
audioset_train_csv = project_dir+'segments/2000max_subset_unbalanced_train_segments.csv'
train_sub_dir = '2000unbalanced_train/audio' # estou lendo em aac pois o linux suporta, no windows tem que ser wav

audioset_eval_csv = project_dir+'segments/subset_eval_segments.csv'
eval_sub_dir = 'eval/audio'

# %% [markdown]
# ## Cnn

# %%
# hiperparâmetros para extração de características
frames = 420 # largura do mel spectogram 
bands = 60 # altura

# %% [markdown]
# ## Carregar dados

# %% [markdown]
# Começe daqui se já tiver os npy salvos

# %%
# Load up numpy arrays to save time if they have already been procesed.

save_dir = data_dir+train_sub_dir+"/2000features/cnn/"
feature_file = os.path.join(save_dir + '_x.npy')
labels_file = os.path.join(save_dir + '_y.npy')
train_x = np.load(feature_file)
train_y = np.load(labels_file)
print(train_x.shape)


save_dir = data_dir+eval_sub_dir+"/2000features/cnn/"
feature_file = os.path.join(save_dir + '_x.npy')
labels_file = os.path.join(save_dir + '_y.npy')
eval_x = np.load(feature_file)
eval_y = np.load(labels_file)
print(eval_x.shape)
# Out:
# (10950, 60, 420)
# (532, 60, 420)

# %%
from keras import Model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Input
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import SGD, Adam
#from keras.callbacks import EarlyStopping
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score
#from keras.utils import np_utils

from keras.layers import BatchNormalization

from keras.layers.merge import concatenate


from keras.regularizers import l2


# Inspirado em
#https://github.com/karoldvl/echonet/blob/1f1c864e4230688af0b338b60756a967dc9127cd/examples/esc_convnet_paper.py

num_labels = train_y.shape[1]
n_dim = np.empty((60,420,1)).shape
# filters of size 1x1 
f_size = 1



# input: 60x420 data frames with 1 channels => (60,420,1) tensors
audio_input  = Input(shape=(n_dim),name='audio_input')

#  kernel_regularizer=l2(0.001)

audio = Convolution2D(80, (57,6),strides=f_size, kernel_initializer='uniform', input_shape=n_dim)(audio_input)
audio = Activation('relu')(audio)
audio = MaxPooling2D(pool_size=(4, 3),strides=(1,3))(audio)
audio = Dropout(0.5)(audio)

audio = BatchNormalization()(audio)

# kernel_regularizer=l2(0.001)
audio = Convolution2D(80, (1,3),strides=f_size, kernel_initializer='uniform')(audio)  # era pra ser init=uniform(0.001),
audio = Activation('relu')(audio)
audio = MaxPooling2D(pool_size=(1, 3),strides=(1,3))(audio)

audio = BatchNormalization()(audio)

# flatten output into a single dimension 
# Keras will do shape inference automatically
audio = Flatten()(audio)

# then a fully connected NN layer
audio = Dense(5000)(audio)
audio = Activation('relu')(audio)
audio = Dropout(0.5)(audio)

# then a fully connected NN layer
audio = Dense(1000)(audio)
audio = Activation('relu')(audio)


## TESTE: SERÁ QUE A CAUSA DA MELHORA SÃO OS LAYERS ADICIONAIS?
audio = concatenate([audio, audio])
audio = Dense(500, activation='relu')(audio)
audio = Dropout(0.5)(audio)
audio = Dense(500, activation='relu')(audio)


main_output = Dense(num_labels, activation='sigmoid',name='main_output')(audio)


model = Model(inputs=[audio_input], outputs=main_output)


sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)

model.compile(loss='binary_crossentropy', metrics=['binary_accuracy'], optimizer=sgd)

# %%
# adicionando uma dimensão ao final
from keras.backend import expand_dims
expanded_train_x = np.expand_dims(train_x, axis=-1)
expanded_eval_x = np.expand_dims(eval_x, axis=-1)

# %%
expanded_train_x.shape
# Out:
# (10950, 60, 420, 1)

# %%
metrics = custom_metrics()

#from keras.callbacks import EarlyStopping
#earlyStopping = EarlyStopping(monitor='val_loss', patience=20, verbose=0, mode='auto')
#reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=10, min_lr=0.0001, verbose=1)

history = model.fit(x = expanded_train_x,
                    y = train_y,
                    validation_data=(expanded_eval_x,eval_y),
                    batch_size=32,
                    epochs=40,
                    callbacks=[metrics])
# Out:
# Train on 10950 samples, validate on 532 samples
# Epoch 1/40
# 10950/10950 [==============================] - 8s 770us/step - loss: 0.4270 - binary_accuracy: 0.8290 - val_loss: 0.7004 - val_binary_accuracy: 0.7787
# Epoch 2/40
# 10950/10950 [==============================] - 7s 609us/step - loss: 0.3861 - binary_accuracy: 0.8384 - val_loss: 0.7034 - val_binary_accuracy: 0.7468
# Epoch 3/40
# 10950/10950 [==============================] - 7s 616us/step - loss: 0.3755 - binary_accuracy: 0.8416 - val_loss: 0.5779 - val_binary_accuracy: 0.7871
# Epoch 4/40
# 10950/10950 [==============================] - 7s 614us/step - loss: 0.3684 - binary_accuracy: 0.8423 - val_loss: 0.5843 - val_binary_accuracy: 0.7766
# Epoch 5/40
# 10950/10950 [==============================] - 7s 612us/step - loss: 0.3625 - binary_accuracy: 0.8444 - val_loss: 0.4499 - val_binary_accuracy: 0.8107
# Epoch 6/40
# 10950/10950 [==============================] - 7s 611us/step - loss: 0.3580 - binary_accuracy: 0.8470 - val_loss: 0.4990 - val_binary_accuracy: 0.7978
# Epoch 7/40
# 10950/10950 [==============================] - 7s 607us/step - loss: 0.3527 - binary_accuracy: 0.8474 - val_loss: 0.4986 - val_binary_accuracy: 0.7932
# Epoch 8/40
# 10950/10950 [==============================] - 7s 616us/step - loss: 0.3502 - binary_accuracy: 0.8496 - val_loss: 0.4750 - val_binary_accuracy: 0.8075
# Epoch 9/40
# 10950/10950 [==============================] - 7s 613us/step - loss: 0.3451 - binary_accuracy: 0.8503 - val_loss: 0.4584 - val_binary_accuracy: 0.8222
# Epoch 10/40
# 10950/10950 [==============================] - 7s 613us/step - loss: 0.3405 - binary_accuracy: 0.8532 - val_loss: 0.4407 - val_binary_accuracy: 0.8225
# Epoch 11/40
# 10950/10950 [==============================] - 7s 617us/step - loss: 0.3399 - binary_accuracy: 0.8538 - val_loss: 0.4039 - val_binary_accuracy: 0.8271
# Epoch 12/40
# 10950/10950 [==============================] - 7s 618us/step - loss: 0.3348 - binary_accuracy: 0.8558 - val_loss: 0.4609 - val_binary_accuracy: 0.8059
# Epoch 13/40
# 10950/10950 [==============================] - 7s 614us/step - loss: 0.3319 - binary_accuracy: 0.8566 - val_loss: 0.4412 - val_binary_accuracy: 0.8209
# Epoch 14/40
# 10950/10950 [==============================] - 7s 612us/step - loss: 0.3256 - binary_accuracy: 0.8594 - val_loss: 0.3757 - val_binary_accuracy: 0.8515
# Epoch 15/40
# 10950/10950 [==============================] - 7s 611us/step - loss: 0.3247 - binary_accuracy: 0.8594 - val_loss: 0.4508 - val_binary_accuracy: 0.8096
# Epoch 16/40
# 10950/10950 [==============================] - 7s 620us/step - loss: 0.3202 - binary_accuracy: 0.8616 - val_loss: 0.3948 - val_binary_accuracy: 0.8400
# Epoch 17/40
# 10950/10950 [==============================] - 7s 617us/step - loss: 0.3170 - binary_accuracy: 0.8628 - val_loss: 0.4179 - val_binary_accuracy: 0.8252
# Epoch 18/40
# 10950/10950 [==============================] - 7s 616us/step - loss: 0.3141 - binary_accuracy: 0.8638 - val_loss: 0.3733 - val_binary_accuracy: 0.8424
# Epoch 19/40
# 10950/10950 [==============================] - 7s 603us/step - loss: 0.3097 - binary_accuracy: 0.8658 - val_loss: 0.3667 - val_binary_accuracy: 0.8453
# Epoch 20/40
# 10950/10950 [==============================] - 7s 615us/step - loss: 0.3058 - binary_accuracy: 0.8670 - val_loss: 0.4037 - val_binary_accuracy: 0.8394
# Epoch 21/40
# 10950/10950 [==============================] - 7s 608us/step - loss: 0.3021 - binary_accuracy: 0.8685 - val_loss: 0.3919 - val_binary_accuracy: 0.8383
# Epoch 22/40
# 10950/10950 [==============================] - 7s 620us/step - loss: 0.3007 - binary_accuracy: 0.8685 - val_loss: 0.3676 - val_binary_accuracy: 0.8499
# Epoch 23/40
# 10950/10950 [==============================] - 7s 615us/step - loss: 0.2948 - binary_accuracy: 0.8732 - val_loss: 0.4036 - val_binary_accuracy: 0.8432
# Epoch 24/40
# 10950/10950 [==============================] - 7s 612us/step - loss: 0.2920 - binary_accuracy: 0.8737 - val_loss: 0.4086 - val_binary_accuracy: 0.8298
# Epoch 25/40
# 10950/10950 [==============================] - 7s 619us/step - loss: 0.2916 - binary_accuracy: 0.8729 - val_loss: 0.3870 - val_binary_accuracy: 0.8303
# Epoch 26/40
# 10950/10950 [==============================] - 7s 615us/step - loss: 0.2871 - binary_accuracy: 0.8762 - val_loss: 0.4222 - val_binary_accuracy: 0.8230
# Epoch 27/40
# 10950/10950 [==============================] - 7s 614us/step - loss: 0.2853 - binary_accuracy: 0.8764 - val_loss: 0.4055 - val_binary_accuracy: 0.8298
# Epoch 28/40
# 10950/10950 [==============================] - 7s 617us/step - loss: 0.2818 - binary_accuracy: 0.8783 - val_loss: 0.3905 - val_binary_accuracy: 0.8467
# Epoch 29/40
# 10950/10950 [==============================] - 7s 617us/step - loss: 0.2787 - binary_accuracy: 0.8781 - val_loss: 0.3815 - val_binary_accuracy: 0.8394
# Epoch 30/40
# 10950/10950 [==============================] - 7s 626us/step - loss: 0.2736 - binary_accuracy: 0.8809 - val_loss: 0.3544 - val_binary_accuracy: 0.8488
# Epoch 31/40
# 10950/10950 [==============================] - 7s 613us/step - loss: 0.2701 - binary_accuracy: 0.8831 - val_loss: 0.3981 - val_binary_accuracy: 0.8370
# Epoch 32/40
# 10950/10950 [==============================] - 7s 616us/step - loss: 0.2663 - binary_accuracy: 0.8840 - val_loss: 0.4114 - val_binary_accuracy: 0.8421
# Epoch 33/40
# 10950/10950 [==============================] - 7s 619us/step - loss: 0.2627 - binary_accuracy: 0.8862 - val_loss: 0.4130 - val_binary_accuracy: 0.8324
# Epoch 34/40
# 10950/10950 [==============================] - 7s 612us/step - loss: 0.2600 - binary_accuracy: 0.8882 - val_loss: 0.3721 - val_binary_accuracy: 0.8448
# Epoch 35/40
# 10950/10950 [==============================] - 7s 617us/step - loss: 0.2547 - binary_accuracy: 0.8897 - val_loss: 0.4163 - val_binary_accuracy: 0.8292
# Epoch 36/40
# 10950/10950 [==============================] - 7s 612us/step - loss: 0.2585 - binary_accuracy: 0.8882 - val_loss: 0.3737 - val_binary_accuracy: 0.8381
# Epoch 37/40
# 10950/10950 [==============================] - 7s 610us/step - loss: 0.2496 - binary_accuracy: 0.8914 - val_loss: 0.3780 - val_binary_accuracy: 0.8483
# Epoch 38/40
# 10950/10950 [==============================] - 7s 615us/step - loss: 0.2466 - binary_accuracy: 0.8926 - val_loss: 0.3931 - val_binary_accuracy: 0.8445
# Epoch 39/40
# 10950/10950 [==============================] - 7s 614us/step - loss: 0.2428 - binary_accuracy: 0.8945 - val_loss: 0.3678 - val_binary_accuracy: 0.8518
# Epoch 40/40
# 10950/10950 [==============================] - 7s 611us/step - loss: 0.2406 - binary_accuracy: 0.8962 - val_loss: 0.4089 - val_binary_accuracy: 0.8343

# %%
plot_history(history)
# Out:
# History keys: ['loss', 'val_binary_accuracy', 'val_loss', 'binary_accuracy']

# %%
plot_metrics(metrics)

# %%
pred_y = model.predict([expanded_eval_x])
pred_y[pred_y>=0.5] = 1
pred_y[pred_y<0.5] = 0


from sklearn.metrics import hamming_loss
print(hamming_loss(eval_y,pred_y))

# a diferença entre o ground truth e predições será toda 0 quando os dois forem iguais
## Então buscamos desses não dão tudo 0 e tiramos o inverso disso
predicted_diference = eval_y-pred_y
correcly_predicted = (np.where(~(predicted_diference).any(axis=1))[0])
print("Exact match:",correcly_predicted.shape[0])
print("Accuracy of Exact match:", float(correcly_predicted.shape[0])/eval_y.shape[0])

## If you want to make sure that they are really equal
#for x in correcly_predicted:
#    print np.array_equal(predictions[x], eval_y[x])
# Out:
# 0.165682062299
# ('Exact match:', 171)
# ('Accuracy of Exact match:', 0.32142857142857145)

# %%
labels = ["Wind","Thunder","Rain","Ocean","Fire","Explosion","Gunshot, gunfire"]
multilabel_confusion_matrix(eval_y,pred_y,len(labels))
# Out:
# Multilabel Confusion Matrix
#   TP,   FP,     TN,     FN,
# 0 66	34	325	107
# 1 16	16	463	37
# 2 53	59	381	39
# 3 12	24	446	50
# 4 14	41	431	46
# 5 19	24	453	36
# 6 64	6	364	98
# Σ 244	204	2863	413
#
# F1 Score: 0.441629
# Recall: 0.371385
# Precision: 0.544643
# Hamming Loss: 0.165682

# %%
model.save('modelos_salvos/2000audio_concat_cnn.h5') 
np.save('modelos_salvos/audio_concat_history.npy', history.history)
