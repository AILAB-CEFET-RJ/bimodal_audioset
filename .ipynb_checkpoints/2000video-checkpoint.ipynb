# %%
# Use CPU only
#import os
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
#os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import h5py

import cv2
import sys
import itertools


np.random.seed(1337)
from tensorflow import set_random_seed
set_random_seed(1337)

from utils import *
# Out:
# Using TensorFlow backend.

# %%
project_dir = '/home/rabreu/projeto_multimodal/'
data_dir = project_dir+'data/'

audioset_indices_csv = project_dir+'segments/subset_class_labels_indices.csv'

## pegando dataset desbalanceado, que eu balanceei para 600 ocorrências para cada classe
audioset_train_csv = project_dir+'segments/2000max_subset_unbalanced_train_segments.csv'
train_sub_dir = '2000unbalanced_train/video'

audioset_eval_csv = project_dir+'segments/subset_eval_segments.csv'
eval_sub_dir = 'eval/video'

# %%
fps_trimmed = 3 # get four frames each second
max_frames = 32 # cut the video past this treshold
frame_size = 32 # 32x32 pixels

# %% [markdown]
# ### Salvando dados

# %% [markdown]
# Salva videos e features relativos ao vídeo

# %%
def parse_video_files(parent_dir,sub_dir,csv_file,file_ext='*.mp4'):
    ### HARDCODED VALUE: 3 color channel for images
    features = np.empty((0,max_frames,frame_size,frame_size,3))
    file_labels = []
    count  = 0
    #for label, sub_dir in enumerate(sub_dirs):
    for fn in natural_sort(glob.glob(os.path.join(parent_dir, sub_dir, file_ext))):
        print('Processing Line #' + str(count))
        # The print() calls here are just for debugging. Feel free to remove them.
        print(fn)
        cap = cv2.VideoCapture(fn)
        fps = cap.get(5)
        frames = []
        while(cap.isOpened()):
            frameId = cap.get(1) #current frame number
            ret, frame = cap.read()
            if (ret != True):
                break
            if (len(frames) >= max_frames):
                break
            if (frameId % (np.floor(fps/fps_trimmed)) == 0):
                frame=cv2.resize(frame,(frame_size,frame_size),interpolation=cv2.INTER_AREA)
                #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                frames.append(frame)
                #plt.imshow(frame)
                #plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
                #plt.show()

                #filename = imagesFolder + "/image_" +  str(int(frameId)) + ".jpg"
                #cv2.imwrite(filename, frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        # equalize sequence length
        if len(frames) < max_frames:
            blank_frame = np.zeros((frame_size, frame_size,3))
            for _ in xrange(max_frames - len(frames)):
                frames.append(blank_frame)

        cap.release()
        cv2.destroyAllWindows()
        frames=np.array(frames)
        #print('Frames -->',frames.shape,'Features -->',features.shape)
        #features = np.stack((features, frames),axis=0)
        # insert frame sequence into the features set
        features = np.append(features, [frames], axis=0)
        #print('features stacked to pre-existing features array')
        #print('features numpy array size = ' + str(features.size))

        # Need to get the labels for each clip from the CSV file
        rownum = fn.split(sub_dir)[1].split('/')[1].split('_')[0]
        print('rownum = ' + str(rownum))
        labels = (get_file_name_labels_from_audioset_csv(rownum,csv_file,audioset_indices_csv))
        print('Labels = '+str(labels))
        file_labels.append(labels)

        count += 1

    return np.array(features), np.array(file_labels)

# %%
## já que estamos aqui, vamos Extrair features do balanced dataset também

features, labels = parse_video_files(data_dir,"balanced_train/video",audioset_train_csv,file_ext='*.mp4')
save_dir = data_dir+"balanced_train/audio"+"/features/"
assure_path_exists(save_dir)
save_files(save_dir,features,labels)
# Out:
# Processing Line #0
# /home/rabreu/projeto_multimodal/data/balanced_train/video/0_--aaILOrkII.mp4
# rownum = 0
# Labels = [5]
# Processing Line #1
# /home/rabreu/projeto_multimodal/data/balanced_train/video/1_-99daJhXYJY.mp4
# rownum = 1
# Labels = [5]
# Processing Line #2
# /home/rabreu/projeto_multimodal/data/balanced_train/video/2_-JKLmqDk9p8.mp4
# rownum = 2
# Labels = [0]
# Processing Line #3
# /home/rabreu/projeto_multimodal/data/balanced_train/video/3_-JOKwS64mRU.mp4
# rownum = 3
# Labels = [1]
# Processing Line #4
# /home/rabreu/projeto_multimodal/data/balanced_train/video/4_-RAdrtCW1hI.mp4
# rownum = 4
# Labels = [5]
# Processing Line #5
# /home/rabreu/projeto_multimodal/data/balanced_train/video/6_-b_10b-orX4.mp4
# rownum = 6
# Labels = [2]
# Processing Line #6
# /home/rabreu/projeto_multimodal/data/balanced_train/video/7_-cQV8iXK3pQ.mp4
# rownum = 7
# Labels = [2, 1]
# Processing Line #7
# /home/rabreu/projeto_multimodal/data/balanced_train/video/8_-cWrzrfVdMQ.mp4
# rownum = 8
# Labels = [0, 3]
# Processing Line #8
# /home/rabreu/projeto_multimodal/data/balanced_train/video/9_-fwZGpmJNhw.mp4
# rownum = 9
# Labels = [2, 1]
# Processing Line #9
# /home/rabreu/projeto_multimodal/data/balanced_train/video/10_-i-9C48tduw.mp4
# rownum = 10
# Labels = [5]
# Processing Line #10
# /home/rabreu/projeto_multimodal/data/balanced_train/video/11_-tL4aWGx01s.mp4
# rownum = 11
# Labels = [2]
# Processing Line #11
# /home/rabreu/projeto_multimodal/data/balanced_train/video/13_0-DkUF7TnnI.mp4
# rownum = 13
# Labels = [5]
# Processing Line #12
# /home/rabreu/projeto_multimodal/data/balanced_train/video/14_09zT8qlC384.mp4
# rownum = 14
# Labels = [6]
# Processing Line #13
# /home/rabreu/projeto_multimodal/data/balanced_train/video/15_0HDoqcA727o.mp4
# rownum = 15
# Labels = [2, 1]
# Processing Line #14
# /home/rabreu/projeto_multimodal/data/balanced_train/video/16_0Qj73JaG8Ik.mp4
# rownum = 16
# Labels = [4]
# Processing Line #15
# /home/rabreu/projeto_multimodal/data/balanced_train/video/17_0YsXXGEVmy8.mp4
# rownum = 17
# Labels = [1]
# Processing Line #16
# /home/rabreu/projeto_multimodal/data/balanced_train/video/18_0o4vHYlTPBA.mp4
# rownum = 18
# Labels = [2]
# Processing Line #17
# /home/rabreu/projeto_multimodal/data/balanced_train/video/19_0rcgzQpsWYs.mp4
# rownum = 19
# Labels = [0]
# Processing Line #18
# /home/rabreu/projeto_multimodal/data/balanced_train/video/20_0xps9c25LqE.mp4
# rownum = 20
# Labels = [3]
# Processing Line #19
# /home/rabreu/projeto_multimodal/data/balanced_train/video/21_11-d3rWQxZY.mp4
# rownum = 21
# Labels = [2]
# Processing Line #20
# /home/rabreu/projeto_multimodal/data/balanced_train/video/22_1AlmsqlPdwM.mp4
# rownum = 22
# Labels = [6]
# Processing Line #21
# /home/rabreu/projeto_multimodal/data/balanced_train/video/23_1Co1uyI6Ulw.mp4
# rownum = 23
# Labels = [1]
# Processing Line #22
# /home/rabreu/projeto_multimodal/data/balanced_train/video/24_1CouJesdH7M.mp4
# rownum = 24
# Labels = [0]
# Processing Line #23
# /home/rabreu/projeto_multimodal/data/balanced_train/video/25_1OHxLcGzhv0.mp4
# rownum = 25
# Labels = [3]
# Processing Line #24
# /home/rabreu/projeto_multimodal/data/balanced_train/video/26_1OM5619KGEI.mp4
# rownum = 26
# Labels = [0]
# Processing Line #25
# /home/rabreu/projeto_multimodal/data/balanced_train/video/27_1nYZnNEKI6o.mp4
# rownum = 27
# Labels = [2]
# Processing Line #26
# /home/rabreu/projeto_multimodal/data/balanced_train/video/28_27rCZL5yPU4.mp4
# rownum = 28
# Labels = [5]
# Processing Line #27
# /home/rabreu/projeto_multimodal/data/balanced_train/video/29_2Gu16Qh4EHw.mp4
# rownum = 29
# Labels = [2]
# Processing Line #28
# /home/rabreu/projeto_multimodal/data/balanced_train/video/30_2LZ0q78OWZE.mp4
# rownum = 30
# Labels = [6]
# Processing Line #29
# /home/rabreu/projeto_multimodal/data/balanced_train/video/31_2Lam7ljO3Is.mp4
# rownum = 31
# Labels = [0, 3]
# Processing Line #30
# /home/rabreu/projeto_multimodal/data/balanced_train/video/32_2aCeBLWVL68.mp4
# rownum = 32
# Labels = [2]
# Processing Line #31
# /home/rabreu/projeto_multimodal/data/balanced_train/video/33_2jFE-MKRmPw.mp4
# rownum = 33
# Labels = [2]
# Processing Line #32
# /home/rabreu/projeto_multimodal/data/balanced_train/video/34_3K4JqHLgq9I.mp4
# rownum = 34
# Labels = [2, 1]
# Processing Line #33
# /home/rabreu/projeto_multimodal/data/balanced_train/video/35_3RKZM0WIRbk.mp4
# rownum = 35
# Labels = [3]
# Processing Line #34
# /home/rabreu/projeto_multimodal/data/balanced_train/video/36_3ZEzvNaHWPE.mp4
# rownum = 36
# Labels = [0]
# Processing Line #35
# /home/rabreu/projeto_multimodal/data/balanced_train/video/38_3eGOQOcKkAE.mp4
# rownum = 38
# Labels = [2]
# Processing Line #36
# /home/rabreu/projeto_multimodal/data/balanced_train/video/39_3j3AM4taI-U.mp4
# rownum = 39
# Labels = [5]
# Processing Line #37
# /home/rabreu/projeto_multimodal/data/balanced_train/video/40_3oF7NLTzoxc.mp4
# rownum = 40
# Labels = [2, 1]
# Processing Line #38
# /home/rabreu/projeto_multimodal/data/balanced_train/video/41_3udWS-cMb-8.mp4
# rownum = 41
# Labels = [6]
# Processing Line #39
# /home/rabreu/projeto_multimodal/data/balanced_train/video/42_3y2aZEs1F5s.mp4
# rownum = 42
# Labels = [4]
# Processing Line #40
# /home/rabreu/projeto_multimodal/data/balanced_train/video/43_41SLp0ph65A.mp4
# rownum = 43
# Labels = [0, 3]
# Processing Line #41
# /home/rabreu/projeto_multimodal/data/balanced_train/video/44_472uoq6erhc.mp4
# rownum = 44
# Labels = [3]
# Processing Line #42
# /home/rabreu/projeto_multimodal/data/balanced_train/video/45_49kPjptbt38.mp4
# rownum = 45
# Labels = [2]
# Processing Line #43
# /home/rabreu/projeto_multimodal/data/balanced_train/video/46_4JnYkujJGRA.mp4
# rownum = 46
# Labels = [5]
# Processing Line #44
# /home/rabreu/projeto_multimodal/data/balanced_train/video/48_4hwwaJQV7Go.mp4
# rownum = 48
# Labels = [0, 3]
# Processing Line #45
# /home/rabreu/projeto_multimodal/data/balanced_train/video/49_4lNM6Ah99hw.mp4
# rownum = 49
# Labels = [0]
# Processing Line #46
# /home/rabreu/projeto_multimodal/data/balanced_train/video/50_4tQiC9E6Mxc.mp4
# rownum = 50
# Labels = [2]
# Processing Line #47
# /home/rabreu/projeto_multimodal/data/balanced_train/video/51_5190n8RJI_k.mp4
# rownum = 51
# Labels = [0, 3]
# Processing Line #48
# /home/rabreu/projeto_multimodal/data/balanced_train/video/52_54EJiYdS03s.mp4
# rownum = 52
# Labels = [0]
# Processing Line #49
# /home/rabreu/projeto_multimodal/data/balanced_train/video/53_5NqDdoLAUjE.mp4
# rownum = 53
# Labels = [5]
# Processing Line #50
# /home/rabreu/projeto_multimodal/data/balanced_train/video/54_5ddBDVLBRFQ.mp4
# rownum = 54
# Labels = [0]
# Processing Line #51
# /home/rabreu/projeto_multimodal/data/balanced_train/video/55_5kM5TBYx07g.mp4
# rownum = 55
# Labels = [0, 3]
# Processing Line #52
# /home/rabreu/projeto_multimodal/data/balanced_train/video/56_5piIqrQB5rU.mp4
# rownum = 56
# Labels = [2, 1]
# Processing Line #53
# /home/rabreu/projeto_multimodal/data/balanced_train/video/57_5znApAp2Gcc.mp4
# rownum = 57
# Labels = [5]
# Processing Line #54
# /home/rabreu/projeto_multimodal/data/balanced_train/video/58_66wgrFPRzZU.mp4
# rownum = 58
# Labels = [5]
# Processing Line #55
# /home/rabreu/projeto_multimodal/data/balanced_train/video/59_69aQWOcvmoI.mp4
# rownum = 59
# Labels = [5]
# Processing Line #56
# /home/rabreu/projeto_multimodal/data/balanced_train/video/60_6O4Zpv-cAXY.mp4
# rownum = 60
# Labels = [2]
# Processing Line #57
# /home/rabreu/projeto_multimodal/data/balanced_train/video/61_6OHetw29o_A.mp4
# rownum = 61
# Labels = [5]
# Processing Line #58
# /home/rabreu/projeto_multimodal/data/balanced_train/video/62_6j76kSyiOCA.mp4
# rownum = 62
# Labels = [0, 3]
# Processing Line #59
# /home/rabreu/projeto_multimodal/data/balanced_train/video/63_6j_0JxixrG8.mp4
# rownum = 63
# Labels = [0]
# Processing Line #60
# /home/rabreu/projeto_multimodal/data/balanced_train/video/64_6kguB8XWB64.mp4
# rownum = 64
# Labels = [2]
# Processing Line #61
# /home/rabreu/projeto_multimodal/data/balanced_train/video/65_6lhRhz7Ki_0.mp4
# rownum = 65
# Labels = [0, 3]
# Processing Line #62
# /home/rabreu/projeto_multimodal/data/balanced_train/video/66_6mBd8XtwkvM.mp4
# rownum = 66
# Labels = [3]
# Processing Line #63
# /home/rabreu/projeto_multimodal/data/balanced_train/video/67_6qi1KV9MoO0.mp4
# rownum = 67
# Labels = [3]
# Processing Line #64
# /home/rabreu/projeto_multimodal/data/balanced_train/video/68_76pXCH-hvb4.mp4
# rownum = 68
# Labels = [6]
# Processing Line #65
# /home/rabreu/projeto_multimodal/data/balanced_train/video/69_78R6KgsSPRk.mp4
# rownum = 69
# Labels = [5]
# Processing Line #66
# /home/rabreu/projeto_multimodal/data/balanced_train/video/70_7Bfg94jYDVI.mp4
# rownum = 70
# Labels = [2, 1]
# Processing Line #67
# /home/rabreu/projeto_multimodal/data/balanced_train/video/71_7Leh-jVFjjg.mp4
# rownum = 71
# Labels = [4]
# Processing Line #68
# /home/rabreu/projeto_multimodal/data/balanced_train/video/72_7gZqP4-Y0Cw.mp4
# rownum = 72
# Labels = [5]
# Processing Line #69
# /home/rabreu/projeto_multimodal/data/balanced_train/video/73_7rVjlroRQ64.mp4
# rownum = 73
# Labels = [5]
# Processing Line #70
# /home/rabreu/projeto_multimodal/data/balanced_train/video/75_7sU0jAHPJG0.mp4
# rownum = 75
# Labels = [6]
# Processing Line #71
# /home/rabreu/projeto_multimodal/data/balanced_train/video/76_89hj7G1AWYY.mp4
# rownum = 76
# Labels = [5]
# Processing Line #72
# /home/rabreu/projeto_multimodal/data/balanced_train/video/77_8B3cEMueaDc.mp4
# rownum = 77
# Labels = [2, 1]
# Processing Line #73
# /home/rabreu/projeto_multimodal/data/balanced_train/video/78_8Bcmyjk3TYk.mp4
# rownum = 78
# Labels = [3]
# Processing Line #74
# /home/rabreu/projeto_multimodal/data/balanced_train/video/79_8CtGons_X48.mp4
# rownum = 79
# Labels = [5]
# Processing Line #75
# /home/rabreu/projeto_multimodal/data/balanced_train/video/80_8D4L97zM7x4.mp4
# rownum = 80
# Labels = [6]
# Processing Line #76
# /home/rabreu/projeto_multimodal/data/balanced_train/video/81_8FYoIwYkoWY.mp4
# rownum = 81
# Labels = [3]
# Processing Line #77
# /home/rabreu/projeto_multimodal/data/balanced_train/video/82_8PgDC2GUx9k.mp4
# rownum = 82
# Labels = [5]
# Processing Line #78
# /home/rabreu/projeto_multimodal/data/balanced_train/video/83_8Ti-qa2gvoc.mp4
# rownum = 83
# Labels = [0, 3]
# Processing Line #79
# /home/rabreu/projeto_multimodal/data/balanced_train/video/84_8VbJJQXwX4o.mp4
# rownum = 84
# Labels = [3]
# Processing Line #80
# /home/rabreu/projeto_multimodal/data/balanced_train/video/85_8a2OeWS3G-A.mp4
# rownum = 85
# Labels = [0]
# Processing Line #81
# /home/rabreu/projeto_multimodal/data/balanced_train/video/86_8oa7QzW-IBc.mp4
# rownum = 86
# Labels = [2]
# Processing Line #82
# /home/rabreu/projeto_multimodal/data/balanced_train/video/87_8pJUJvPfIx0.mp4
# rownum = 87
# Labels = [5]
# Processing Line #83
# /home/rabreu/projeto_multimodal/data/balanced_train/video/88_8ryifCe_sIU.mp4
# rownum = 88
# Labels = [2]
# Processing Line #84
# /home/rabreu/projeto_multimodal/data/balanced_train/video/89_9Bg7XK1Uoyw.mp4
# rownum = 89
# Labels = [4]
# Processing Line #85
# /home/rabreu/projeto_multimodal/data/balanced_train/video/90_9BkxqopOLQo.mp4
# rownum = 90
# Labels = [6]
# Processing Line #86
# /home/rabreu/projeto_multimodal/data/balanced_train/video/91_9CCRS3MCwXI.mp4
# rownum = 91
# Labels = [5]
# Processing Line #87
# /home/rabreu/projeto_multimodal/data/balanced_train/video/92_9Cx-qZZAyQg.mp4
# rownum = 92
# Labels = [6]
# Processing Line #88
# /home/rabreu/projeto_multimodal/data/balanced_train/video/93_9EzV2FqY2y8.mp4
# rownum = 93
# Labels = [0, 3]
# Processing Line #89
# /home/rabreu/projeto_multimodal/data/balanced_train/video/94_9FH7i5Q4rGI.mp4
# rownum = 94
# Labels = [6]
# Processing Line #90
# /home/rabreu/projeto_multimodal/data/balanced_train/video/95_9FpX26dPaSQ.mp4
# rownum = 95
# Labels = [6]
# Processing Line #91
# /home/rabreu/projeto_multimodal/data/balanced_train/video/96_9It3a2bN2Uw.mp4
# rownum = 96
# Labels = [3]
# Processing Line #92
# /home/rabreu/projeto_multimodal/data/balanced_train/video/97_9MVCwolWlLE.mp4
# rownum = 97
# Labels = [5]
# Processing Line #93
# /home/rabreu/projeto_multimodal/data/balanced_train/video/98_9Pd12SkMum4.mp4
# rownum = 98
# Labels = [6]
# Processing Line #94
# /home/rabreu/projeto_multimodal/data/balanced_train/video/99_9UP7L34-zus.mp4
# rownum = 99
# Labels = [6]
# Processing Line #95
# /home/rabreu/projeto_multimodal/data/balanced_train/video/100_9W--1bU_zjg.mp4
# rownum = 100
# Labels = [4]
# Processing Line #96
# /home/rabreu/projeto_multimodal/data/balanced_train/video/101_9Wfg4h6CVqo.mp4
# rownum = 101
# Labels = [1]
# Processing Line #97
# /home/rabreu/projeto_multimodal/data/balanced_train/video/102_9dzNWsw-W58.mp4
# rownum = 102
# Labels = [2, 1]
# Processing Line #98
# /home/rabreu/projeto_multimodal/data/balanced_train/video/103_9iyQiuuF_CE.mp4
# rownum = 103
# Labels = [2]
# Processing Line #99
# /home/rabreu/projeto_multimodal/data/balanced_train/video/104_9j4IROLuOkE.mp4
# rownum = 104
# Labels = [5]
# Processing Line #100
# /home/rabreu/projeto_multimodal/data/balanced_train/video/105_9kjfu8TUTYk.mp4
# rownum = 105
# Labels = [2, 1]
# Processing Line #101
# /home/rabreu/projeto_multimodal/data/balanced_train/video/106_9nYeNrZ4EPY.mp4
# rownum = 106
# Labels = [0, 3]
# Processing Line #102
# /home/rabreu/projeto_multimodal/data/balanced_train/video/107_9oxMZQOS6sE.mp4
# rownum = 107
# Labels = [6]
# Processing Line #103
# /home/rabreu/projeto_multimodal/data/balanced_train/video/108_9ww0jrYLgZ8.mp4
# rownum = 108
# Labels = [0]
# Processing Line #104
# /home/rabreu/projeto_multimodal/data/balanced_train/video/109_AIthc77KW8w.mp4
# rownum = 109
# Labels = [6]
# Processing Line #105
# /home/rabreu/projeto_multimodal/data/balanced_train/video/110_AJzwtVxRLVU.mp4
# rownum = 110
# Labels = [0]
# Processing Line #106
# /home/rabreu/projeto_multimodal/data/balanced_train/video/112_APYXZHZPCE4.mp4
# rownum = 112
# Labels = [5]
# Processing Line #107
# /home/rabreu/projeto_multimodal/data/balanced_train/video/113_Aai257FTBiQ.mp4
# rownum = 113
# Labels = [3]
# Processing Line #108
# /home/rabreu/projeto_multimodal/data/balanced_train/video/114_Ab51oVS98Qo.mp4
# rownum = 114
# Labels = [2, 1]
# Processing Line #109
# /home/rabreu/projeto_multimodal/data/balanced_train/video/115_AeWRWWba3z4.mp4
# rownum = 115
# Labels = [5]
# Processing Line #110
# /home/rabreu/projeto_multimodal/data/balanced_train/video/116_AgLm7rSg5JA.mp4
# rownum = 116
# Labels = [5]
# Processing Line #111
# /home/rabreu/projeto_multimodal/data/balanced_train/video/117_AsSPcPFgGdE.mp4
# rownum = 117
# Labels = [5]
# Processing Line #112
# /home/rabreu/projeto_multimodal/data/balanced_train/video/118_Au5NjQaR_T0.mp4
# rownum = 118
# Labels = [5]
# Processing Line #113
# /home/rabreu/projeto_multimodal/data/balanced_train/video/119_AuJ8X3TK3cU.mp4
# rownum = 119
# Labels = [2, 1]
# Processing Line #114
# /home/rabreu/projeto_multimodal/data/balanced_train/video/120_B9ZQcIBD4rA.mp4
# rownum = 120
# Labels = [4]
# Processing Line #115
# /home/rabreu/projeto_multimodal/data/balanced_train/video/121_BEuIJ5dw5kY.mp4
# rownum = 121
# Labels = [2, 1]
# Processing Line #116
# /home/rabreu/projeto_multimodal/data/balanced_train/video/122_BJVFqd7WYxA.mp4
# rownum = 122
# Labels = [6]
# Processing Line #117
# /home/rabreu/projeto_multimodal/data/balanced_train/video/123_BQWPvKrN07c.mp4
# rownum = 123
# Labels = [4, 0]
# Processing Line #118
# /home/rabreu/projeto_multimodal/data/balanced_train/video/124_BQWXKuFYuro.mp4
# rownum = 124
# Labels = [4]
# Processing Line #119
# /home/rabreu/projeto_multimodal/data/balanced_train/video/125_BRYojKzC-xY.mp4
# rownum = 125
# Labels = [0, 3]
# Processing Line #120
# /home/rabreu/projeto_multimodal/data/balanced_train/video/126_BSPjTGVP1I4.mp4
# rownum = 126
# Labels = [0, 3]
# Processing Line #121
# /home/rabreu/projeto_multimodal/data/balanced_train/video/127_BVch9SzTjZw.mp4
# rownum = 127
# Labels = [6]
# Processing Line #122
# /home/rabreu/projeto_multimodal/data/balanced_train/video/128_BbLkppp3QZc.mp4
# rownum = 128
# Labels = [6]
# Processing Line #123
# /home/rabreu/projeto_multimodal/data/balanced_train/video/129_Bdi9NEo8cDU.mp4
# rownum = 129
# Labels = [5]
# Processing Line #124
# /home/rabreu/projeto_multimodal/data/balanced_train/video/130_Be0z4cALwJo.mp4
# rownum = 130
# Labels = [0]
# Processing Line #125
# /home/rabreu/projeto_multimodal/data/balanced_train/video/131_BmkqueB0Vrs.mp4
# rownum = 131
# Labels = [3]
# Processing Line #126
# /home/rabreu/projeto_multimodal/data/balanced_train/video/132_BtN6AvD1FyA.mp4
# rownum = 132
# Labels = [6]
# Processing Line #127
# /home/rabreu/projeto_multimodal/data/balanced_train/video/133_By8_wPVT4zg.mp4
# rownum = 133
# Labels = [2, 1]
# Processing Line #128
# /home/rabreu/projeto_multimodal/data/balanced_train/video/134_C2gkVodtiCs.mp4
# rownum = 134
# Labels = [2]
# Processing Line #129
# /home/rabreu/projeto_multimodal/data/balanced_train/video/135_C72bv2YhZ6A.mp4
# rownum = 135
# Labels = [6]
# Processing Line #130
# /home/rabreu/projeto_multimodal/data/balanced_train/video/136_C9SbW7DnSho.mp4
# rownum = 136
# Labels = [3]
# Processing Line #131
# /home/rabreu/projeto_multimodal/data/balanced_train/video/137_CCHRD-G9sfA.mp4
# rownum = 137
# Labels = [0, 3]
# Processing Line #132
# /home/rabreu/projeto_multimodal/data/balanced_train/video/138_CFLiUsZvjqw.mp4
# rownum = 138
# Labels = [5, 4]
# Processing Line #133
# /home/rabreu/projeto_multimodal/data/balanced_train/video/139_CNETKbKHhwc.mp4
# rownum = 139
# Labels = [1]
# Processing Line #134
# /home/rabreu/projeto_multimodal/data/balanced_train/video/140_CNURVtAOhRE.mp4
# rownum = 140
# Labels = [0, 3]
# Processing Line #135
# /home/rabreu/projeto_multimodal/data/balanced_train/video/141_COe52lCaNPk.mp4
# rownum = 141
# Labels = [1]
# Processing Line #136
# /home/rabreu/projeto_multimodal/data/balanced_train/video/143_CSfJWw9cM2s.mp4
# rownum = 143
# Labels = [4]
# Processing Line #137
# /home/rabreu/projeto_multimodal/data/balanced_train/video/144_CXFCW_AHFCk.mp4
# rownum = 144
# Labels = [5]
# Processing Line #138
# /home/rabreu/projeto_multimodal/data/balanced_train/video/145_CcKeBkOVJIY.mp4
# rownum = 145
# Labels = [5, 4]
# Processing Line #139
# /home/rabreu/projeto_multimodal/data/balanced_train/video/146_CelxGPZvoyw.mp4
# rownum = 146
# Labels = [5]
# Processing Line #140
# /home/rabreu/projeto_multimodal/data/balanced_train/video/147_Cl64_nI7A14.mp4
# rownum = 147
# Labels = [5]
# Processing Line #141
# /home/rabreu/projeto_multimodal/data/balanced_train/video/150_D7-J_A8zf2k.mp4
# rownum = 150
# Labels = [0]
# Processing Line #142
# /home/rabreu/projeto_multimodal/data/balanced_train/video/151_DUvF0NeTxPs.mp4
# rownum = 151
# Labels = [0]
# Processing Line #143
# /home/rabreu/projeto_multimodal/data/balanced_train/video/152_Dj6vz-bsHXY.mp4
# rownum = 152
# Labels = [0, 3]
# Processing Line #144
# /home/rabreu/projeto_multimodal/data/balanced_train/video/153_DoRebW9poXU.mp4
# rownum = 153
# Labels = [3]
# Processing Line #145
# /home/rabreu/projeto_multimodal/data/balanced_train/video/154_DsFvp-0mEZA.mp4
# rownum = 154
# Labels = [2, 1]
# Processing Line #146
# /home/rabreu/projeto_multimodal/data/balanced_train/video/155_DwyOjLK00jQ.mp4
# rownum = 155
# Labels = [2]
# Processing Line #147
# /home/rabreu/projeto_multimodal/data/balanced_train/video/156_DzlD845npq4.mp4
# rownum = 156
# Labels = [2, 1]
# Processing Line #148
# /home/rabreu/projeto_multimodal/data/balanced_train/video/157_E-J9vzpZFn4.mp4
# rownum = 157
# Labels = [4]
# Processing Line #149
# /home/rabreu/projeto_multimodal/data/balanced_train/video/158_E5A5jUE-n2c.mp4
# rownum = 158
# Labels = [2, 1]
# Processing Line #150
# /home/rabreu/projeto_multimodal/data/balanced_train/video/159_EJucDkHyC_U.mp4
# rownum = 159
# Labels = [0, 3]
# Processing Line #151
# /home/rabreu/projeto_multimodal/data/balanced_train/video/160_EQoCKPIrT3U.mp4
# rownum = 160
# Labels = [0]
# Processing Line #152
# /home/rabreu/projeto_multimodal/data/balanced_train/video/161_ERYy3X1mx0c.mp4
# rownum = 161
# Labels = [4]
# Processing Line #153
# /home/rabreu/projeto_multimodal/data/balanced_train/video/162_ETiHg0_v210.mp4
# rownum = 162
# Labels = [5]
# Processing Line #154
# /home/rabreu/projeto_multimodal/data/balanced_train/video/163_Ea6wuY5zHDc.mp4
# rownum = 163
# Labels = [6]
# Processing Line #155
# /home/rabreu/projeto_multimodal/data/balanced_train/video/164_EfzNaAVrqFk.mp4
# rownum = 164
# Labels = [0, 3]
# Processing Line #156
# /home/rabreu/projeto_multimodal/data/balanced_train/video/165_Emw8Ax5g3i8.mp4
# rownum = 165
# Labels = [5]
# Processing Line #157
# /home/rabreu/projeto_multimodal/data/balanced_train/video/166_EonsfqQZ0OU.mp4
# rownum = 166
# Labels = [2, 1]
# Processing Line #158
# /home/rabreu/projeto_multimodal/data/balanced_train/video/167_ExKxdQ_Kph0.mp4
# rownum = 167
# Labels = [0]
# Processing Line #159
# /home/rabreu/projeto_multimodal/data/balanced_train/video/168_F7eX5VXbvNo.mp4
# rownum = 168
# Labels = [5]
# Processing Line #160
# /home/rabreu/projeto_multimodal/data/balanced_train/video/169_FCWFhArE1UU.mp4
# rownum = 169
# Labels = [0]
# Processing Line #161
# /home/rabreu/projeto_multimodal/data/balanced_train/video/170_FCjwziBggHE.mp4
# rownum = 170
# Labels = [5]
# Processing Line #162
# /home/rabreu/projeto_multimodal/data/balanced_train/video/171_FGSTvZW_toM.mp4
# rownum = 171
# Labels = [6]
# Processing Line #163
# /home/rabreu/projeto_multimodal/data/balanced_train/video/172_FLgXwU-TviI.mp4
# rownum = 172
# Labels = [6]
# Processing Line #164
# /home/rabreu/projeto_multimodal/data/balanced_train/video/173_FN7VIGq04qE.mp4
# rownum = 173
# Labels = [3]
# Processing Line #165
# /home/rabreu/projeto_multimodal/data/balanced_train/video/174_FO6arunsodo.mp4
# rownum = 174
# Labels = [2]
# Processing Line #166
# /home/rabreu/projeto_multimodal/data/balanced_train/video/175_FPRRNfbcULA.mp4
# rownum = 175
# Labels = [0]
# Processing Line #167
# /home/rabreu/projeto_multimodal/data/balanced_train/video/177_FnkVyKnukpE.mp4
# rownum = 177
# Labels = [5, 4]
# Processing Line #168
# /home/rabreu/projeto_multimodal/data/balanced_train/video/178_FvX4beQXT9M.mp4
# rownum = 178
# Labels = [2]
# Processing Line #169
# /home/rabreu/projeto_multimodal/data/balanced_train/video/179_Fzwa_LIMH2E.mp4
# rownum = 179
# Labels = [4]
# Processing Line #170
# /home/rabreu/projeto_multimodal/data/balanced_train/video/180_G-f6qIJF8Pk.mp4
# rownum = 180
# Labels = [3]
# Processing Line #171
# /home/rabreu/projeto_multimodal/data/balanced_train/video/181_G8l2fpUPWro.mp4
# rownum = 181
# Labels = [5]
# Processing Line #172
# /home/rabreu/projeto_multimodal/data/balanced_train/video/182_G9M3de5mISY.mp4
# rownum = 182
# Labels = [0]
# Processing Line #173
# /home/rabreu/projeto_multimodal/data/balanced_train/video/183_GJd9qaGm92I.mp4
# rownum = 183
# Labels = [2]
# Processing Line #174
# /home/rabreu/projeto_multimodal/data/balanced_train/video/184_GJvWWCx2UuU.mp4
# rownum = 184
# Labels = [5]
# Processing Line #175
# /home/rabreu/projeto_multimodal/data/balanced_train/video/185_GM9C0VWmLpI.mp4
# rownum = 185
# Labels = [6]
# Processing Line #176
# /home/rabreu/projeto_multimodal/data/balanced_train/video/186_GQyqKgXee8A.mp4
# rownum = 186
# Labels = [2]
# Processing Line #177
# /home/rabreu/projeto_multimodal/data/balanced_train/video/187_GXJg8cnsP1k.mp4
# rownum = 187
# Labels = [0, 3]
# Processing Line #178
# /home/rabreu/projeto_multimodal/data/balanced_train/video/188_GYOHFaVFp3o.mp4
# rownum = 188
# Labels = [4, 0]
# Processing Line #179
# /home/rabreu/projeto_multimodal/data/balanced_train/video/189_Gksy214mQWg.mp4
# rownum = 189
# Labels = [6]
# Processing Line #180
# /home/rabreu/projeto_multimodal/data/balanced_train/video/190_GlO3MdKTpd4.mp4
# rownum = 190
# Labels = [1]
# Processing Line #181
# /home/rabreu/projeto_multimodal/data/balanced_train/video/191_Gx-fFUhQ28A.mp4
# rownum = 191
# Labels = [5]
# Processing Line #182
# /home/rabreu/projeto_multimodal/data/balanced_train/video/192_H-QghZBSGjQ.mp4
# rownum = 192
# Labels = [6]
# Processing Line #183
# /home/rabreu/projeto_multimodal/data/balanced_train/video/193_H0adZlMICzE.mp4
# rownum = 193
# Labels = [6]
# Processing Line #184
# /home/rabreu/projeto_multimodal/data/balanced_train/video/194_HDws6xj6J40.mp4
# rownum = 194
# Labels = [0, 3]
# Processing Line #185
# /home/rabreu/projeto_multimodal/data/balanced_train/video/195_HQsOY0A3xoI.mp4
# rownum = 195
# Labels = [0]
# Processing Line #186
# /home/rabreu/projeto_multimodal/data/balanced_train/video/196_H_iDWJ7gbIU.mp4
# rownum = 196
# Labels = [0]
# Processing Line #187
# /home/rabreu/projeto_multimodal/data/balanced_train/video/197_Hjebqbe5wJg.mp4
# rownum = 197
# Labels = [3]
# Processing Line #188
# /home/rabreu/projeto_multimodal/data/balanced_train/video/198_Hn7kIz6Z0ZI.mp4
# rownum = 198
# Labels = [6]
# Processing Line #189
# /home/rabreu/projeto_multimodal/data/balanced_train/video/199_I3zwXIKToXc.mp4
# rownum = 199
# Labels = [5]
# Processing Line #190
# /home/rabreu/projeto_multimodal/data/balanced_train/video/200_I515SEYGbIw.mp4
# rownum = 200
# Labels = [0]
# Processing Line #191
# /home/rabreu/projeto_multimodal/data/balanced_train/video/201_ICdovrQhhrw.mp4
# rownum = 201
# Labels = [0]
# Processing Line #192
# /home/rabreu/projeto_multimodal/data/balanced_train/video/202_ICtHsbPozLU.mp4
# rownum = 202
# Labels = [5]
# Processing Line #193
# /home/rabreu/projeto_multimodal/data/balanced_train/video/203_IHNQUYiF21o.mp4
# rownum = 203
# Labels = [3]
# Processing Line #194
# /home/rabreu/projeto_multimodal/data/balanced_train/video/204_II-fcvc57Jk.mp4
# rownum = 204
# Labels = [0]
# Processing Line #195
# /home/rabreu/projeto_multimodal/data/balanced_train/video/205_IP_9TyuwDc8.mp4
# rownum = 205
# Labels = [0]
# Processing Line #196
# /home/rabreu/projeto_multimodal/data/balanced_train/video/206_IR_ks3y_UTA.mp4
# rownum = 206
# Labels = [5]
# Processing Line #197
# /home/rabreu/projeto_multimodal/data/balanced_train/video/207_ISUgb6HjLbI.mp4
# rownum = 207
# Labels = [2]
# Processing Line #198
# /home/rabreu/projeto_multimodal/data/balanced_train/video/208_IXVXGMPG0dA.mp4
# rownum = 208
# Labels = [4]
# Processing Line #199
# /home/rabreu/projeto_multimodal/data/balanced_train/video/209_IfsJ66GKcr0.mp4
# rownum = 209
# Labels = [3]
# Processing Line #200
# /home/rabreu/projeto_multimodal/data/balanced_train/video/210_IroOVamQZHQ.mp4
# rownum = 210
# Labels = [6]
# Processing Line #201
# /home/rabreu/projeto_multimodal/data/balanced_train/video/211_J652Y8jdAFw.mp4
# rownum = 211
# Labels = [2]
# Processing Line #202
# /home/rabreu/projeto_multimodal/data/balanced_train/video/212_JHgWe45u8NE.mp4
# rownum = 212
# Labels = [2, 1]
# Processing Line #203
# /home/rabreu/projeto_multimodal/data/balanced_train/video/213_JVGj7Bt6Gpg.mp4
# rownum = 213
# Labels = [6]
# Processing Line #204
# /home/rabreu/projeto_multimodal/data/balanced_train/video/214_JfQZeAIHg3s.mp4
# rownum = 214
# Labels = [3]
# Processing Line #205
# /home/rabreu/projeto_multimodal/data/balanced_train/video/215_JjC4SzZwjJg.mp4
# rownum = 215
# Labels = [2]
# Processing Line #206
# /home/rabreu/projeto_multimodal/data/balanced_train/video/216_Jk2B7Mvh6cE.mp4
# rownum = 216
# Labels = [2]
# Processing Line #207
# /home/rabreu/projeto_multimodal/data/balanced_train/video/217_JxzClm8xuDc.mp4
# rownum = 217
# Labels = [3]
# Processing Line #208
# /home/rabreu/projeto_multimodal/data/balanced_train/video/218_JzDXNC3r-FM.mp4
# rownum = 218
# Labels = [6]
# Processing Line #209
# /home/rabreu/projeto_multimodal/data/balanced_train/video/219_K0op6i9ydnM.mp4
# rownum = 219
# Labels = [3]
# Processing Line #210
# /home/rabreu/projeto_multimodal/data/balanced_train/video/220_K5TkfFZk-ro.mp4
# rownum = 220
# Labels = [5]
# Processing Line #211
# /home/rabreu/projeto_multimodal/data/balanced_train/video/221_KH_Cw66-97Q.mp4
# rownum = 221
# Labels = [5]
# Processing Line #212
# /home/rabreu/projeto_multimodal/data/balanced_train/video/222_KOePTJ9eSkQ.mp4
# rownum = 222
# Labels = [2, 1]
# Processing Line #213
# /home/rabreu/projeto_multimodal/data/balanced_train/video/223_KRxPSEBGUi4.mp4
# rownum = 223
# Labels = [2]
# Processing Line #214
# /home/rabreu/projeto_multimodal/data/balanced_train/video/224_Ko9iUJ9Hz50.mp4
# rownum = 224
# Labels = [6]
# Processing Line #215
# /home/rabreu/projeto_multimodal/data/balanced_train/video/225_KrO8LpwM70k.mp4
# rownum = 225
# Labels = [2]
# Processing Line #216
# /home/rabreu/projeto_multimodal/data/balanced_train/video/226_L3Xr_NVi7UM.mp4
# rownum = 226
# Labels = [2]
# Processing Line #217
# /home/rabreu/projeto_multimodal/data/balanced_train/video/227_LMC-xXt6A1g.mp4
# rownum = 227
# Labels = [5]
# Processing Line #218
# /home/rabreu/projeto_multimodal/data/balanced_train/video/228_LSvtwiycIIU.mp4
# rownum = 228
# Labels = [2]
# Processing Line #219
# /home/rabreu/projeto_multimodal/data/balanced_train/video/229_LT5mUSYUzHg.mp4
# rownum = 229
# Labels = [0]
# Processing Line #220
# /home/rabreu/projeto_multimodal/data/balanced_train/video/230_LVW1oLMQksM.mp4
# rownum = 230
# Labels = [4]
# Processing Line #221
# /home/rabreu/projeto_multimodal/data/balanced_train/video/231_L_9U6xDeYcU.mp4
# rownum = 231
# Labels = [0]
# Processing Line #222
# /home/rabreu/projeto_multimodal/data/balanced_train/video/232_L_CRmKhsdfQ.mp4
# rownum = 232
# Labels = [2]
# Processing Line #223
# /home/rabreu/projeto_multimodal/data/balanced_train/video/233_Lx6xaU2Ti7s.mp4
# rownum = 233
# Labels = [0, 3]
# Processing Line #224
# /home/rabreu/projeto_multimodal/data/balanced_train/video/234_LzLvMuwX9Vw.mp4
# rownum = 234
# Labels = [4]
# Processing Line #225
# /home/rabreu/projeto_multimodal/data/balanced_train/video/235_M1xMhk1lCr4.mp4
# rownum = 235
# Labels = [6]
# Processing Line #226
# /home/rabreu/projeto_multimodal/data/balanced_train/video/236_MElc-0XqoSw.mp4
# rownum = 236
# Labels = [2, 1]
# Processing Line #227
# /home/rabreu/projeto_multimodal/data/balanced_train/video/237_MNrctWQxHEA.mp4
# rownum = 237
# Labels = [2]
# Processing Line #228
# /home/rabreu/projeto_multimodal/data/balanced_train/video/238_MQhD1V14Spw.mp4
# rownum = 238
# Labels = [2, 1]
# Processing Line #229
# /home/rabreu/projeto_multimodal/data/balanced_train/video/239_McwJQR6vKDA.mp4
# rownum = 239
# Labels = [5]
# Processing Line #230
# /home/rabreu/projeto_multimodal/data/balanced_train/video/240_MtXS_LO3nNU.mp4
# rownum = 240
# Labels = [5]
# Processing Line #231
# /home/rabreu/projeto_multimodal/data/balanced_train/video/241_N-270xmgaO4.mp4
# rownum = 241
# Labels = [3]
# Processing Line #232
# /home/rabreu/projeto_multimodal/data/balanced_train/video/242_N3I0bQOafN8.mp4
# rownum = 242
# Labels = [5]
# Processing Line #233
# /home/rabreu/projeto_multimodal/data/balanced_train/video/243_NI-ItTGKHuE.mp4
# rownum = 243
# Labels = [5]
# Processing Line #234
# /home/rabreu/projeto_multimodal/data/balanced_train/video/244_NJBlHNAXZZ0.mp4
# rownum = 244
# Labels = [4, 0]
# Processing Line #235
# /home/rabreu/projeto_multimodal/data/balanced_train/video/245_NQnH_JzTxaY.mp4
# rownum = 245
# Labels = [2]
# Processing Line #236
# /home/rabreu/projeto_multimodal/data/balanced_train/video/246_NWjZK1EFZBc.mp4
# rownum = 246
# Labels = [4, 0]
# Processing Line #237
# /home/rabreu/projeto_multimodal/data/balanced_train/video/247_NXPJmaO6vao.mp4
# rownum = 247
# Labels = [0]
# Processing Line #238
# /home/rabreu/projeto_multimodal/data/balanced_train/video/248_NoBvw3b6L7I.mp4
# rownum = 248
# Labels = [6]
# Processing Line #239
# /home/rabreu/projeto_multimodal/data/balanced_train/video/249_NyqqduUCKy0.mp4
# rownum = 249
# Labels = [3]
# Processing Line #240
# /home/rabreu/projeto_multimodal/data/balanced_train/video/250_NzTggyH8J2U.mp4
# rownum = 250
# Labels = [0, 3]
# Processing Line #241
# /home/rabreu/projeto_multimodal/data/balanced_train/video/251_O3mvnbutoqs.mp4
# rownum = 251
# Labels = [2]
# Processing Line #242
# /home/rabreu/projeto_multimodal/data/balanced_train/video/252_OKB62QAF5U8.mp4
# rownum = 252
# Labels = [0]
# Processing Line #243
# /home/rabreu/projeto_multimodal/data/balanced_train/video/253_OLA6yUdoTyo.mp4
# rownum = 253
# Labels = [4]
# Processing Line #244
# /home/rabreu/projeto_multimodal/data/balanced_train/video/254_OMo7qvmsMu4.mp4
# rownum = 254
# Labels = [2, 1]
# Processing Line #245
# /home/rabreu/projeto_multimodal/data/balanced_train/video/255_O_FDe2fRpDM.mp4
# rownum = 255
# Labels = [5]
# Processing Line #246
# /home/rabreu/projeto_multimodal/data/balanced_train/video/256_OjPPHeQXdZk.mp4
# rownum = 256
# Labels = [2]
# Processing Line #247
# /home/rabreu/projeto_multimodal/data/balanced_train/video/257_OplcFe9OOMA.mp4
# rownum = 257
# Labels = [2, 1]
# Processing Line #248
# /home/rabreu/projeto_multimodal/data/balanced_train/video/258_Oq1ygfvQhj0.mp4
# rownum = 258
# Labels = [1]
# Processing Line #249
# /home/rabreu/projeto_multimodal/data/balanced_train/video/260_PsuGhbGDAYw.mp4
# rownum = 260
# Labels = [2]
# Processing Line #250
# /home/rabreu/projeto_multimodal/data/balanced_train/video/261_PwyVufxwAos.mp4
# rownum = 261
# Labels = [6]
# Processing Line #251
# /home/rabreu/projeto_multimodal/data/balanced_train/video/262_PyxzFVgz70M.mp4
# rownum = 262
# Labels = [4]
# Processing Line #252
# /home/rabreu/projeto_multimodal/data/balanced_train/video/263_QDRXDpVbjck.mp4
# rownum = 263
# Labels = [0]
# Processing Line #253
# /home/rabreu/projeto_multimodal/data/balanced_train/video/264_QH3RIg1ypDg.mp4
# rownum = 264
# Labels = [2, 1]
# Processing Line #254
# /home/rabreu/projeto_multimodal/data/balanced_train/video/266_QXNgo7S7Cxw.mp4
# rownum = 266
# Labels = [5]
# Processing Line #255
# /home/rabreu/projeto_multimodal/data/balanced_train/video/267_QXtF7cWgq3M.mp4
# rownum = 267
# Labels = [0, 3]
# Processing Line #256
# /home/rabreu/projeto_multimodal/data/balanced_train/video/268_QbY5RyLsWVM.mp4
# rownum = 268
# Labels = [5]
# Processing Line #257
# /home/rabreu/projeto_multimodal/data/balanced_train/video/269_QcIOX_eo7VU.mp4
# rownum = 269
# Labels = [5]
# Processing Line #258
# /home/rabreu/projeto_multimodal/data/balanced_train/video/270_QdBf5MKpT2o.mp4
# rownum = 270
# Labels = [3]
# Processing Line #259
# /home/rabreu/projeto_multimodal/data/balanced_train/video/271_QfMn5NoHdes.mp4
# rownum = 271
# Labels = [6]
# Processing Line #260
# /home/rabreu/projeto_multimodal/data/balanced_train/video/272_Qhgf--hnohY.mp4
# rownum = 272
# Labels = [6]
# Processing Line #261
# /home/rabreu/projeto_multimodal/data/balanced_train/video/273_QiZ93oKvcjI.mp4
# rownum = 273
# Labels = [5]
# Processing Line #262
# /home/rabreu/projeto_multimodal/data/balanced_train/video/274_QkbHH6LQkr4.mp4
# rownum = 274
# Labels = [5, 4]
# Processing Line #263
# /home/rabreu/projeto_multimodal/data/balanced_train/video/275_QrvCNyQn3HU.mp4
# rownum = 275
# Labels = [5]
# Processing Line #264
# /home/rabreu/projeto_multimodal/data/balanced_train/video/276_R-ieGD15_n8.mp4
# rownum = 276
# Labels = [3]
# Processing Line #265
# /home/rabreu/projeto_multimodal/data/balanced_train/video/277_RCEBJCXKcWA.mp4
# rownum = 277
# Labels = [3]
# Processing Line #266
# /home/rabreu/projeto_multimodal/data/balanced_train/video/278_ROCrWXwzNOk.mp4
# rownum = 278
# Labels = [6]
# Processing Line #267
# /home/rabreu/projeto_multimodal/data/balanced_train/video/279_RcfNij45obU.mp4
# rownum = 279
# Labels = [4]
# Processing Line #268
# /home/rabreu/projeto_multimodal/data/balanced_train/video/280_RdQWZQqJuqo.mp4
# rownum = 280
# Labels = [0]
# Processing Line #269
# /home/rabreu/projeto_multimodal/data/balanced_train/video/281_ReXtuIyu9ls.mp4
# rownum = 281
# Labels = [6]
# Processing Line #270
# /home/rabreu/projeto_multimodal/data/balanced_train/video/282_RfGSlaxcN0w.mp4
# rownum = 282
# Labels = [2]
# Processing Line #271
# /home/rabreu/projeto_multimodal/data/balanced_train/video/283_RhZ8pOgF4D0.mp4
# rownum = 283
# Labels = [6]
# Processing Line #272
# /home/rabreu/projeto_multimodal/data/balanced_train/video/284_RscrFWDOntw.mp4
# rownum = 284
# Labels = [0, 3]
# Processing Line #273
# /home/rabreu/projeto_multimodal/data/balanced_train/video/285_S5ONWWKaMIA.mp4
# rownum = 285
# Labels = [2]
# Processing Line #274
# /home/rabreu/projeto_multimodal/data/balanced_train/video/286_SFJm4TVL-gE.mp4
# rownum = 286
# Labels = [5]
# Processing Line #275
# /home/rabreu/projeto_multimodal/data/balanced_train/video/287_SNH0ywrOEvQ.mp4
# rownum = 287
# Labels = [5]
# Processing Line #276
# /home/rabreu/projeto_multimodal/data/balanced_train/video/288_SavkOa_GGLs.mp4
# rownum = 288
# Labels = [3]
# Processing Line #277
# /home/rabreu/projeto_multimodal/data/balanced_train/video/289_Sr4ufSj2Nq8.mp4
# rownum = 289
# Labels = [5]
# Processing Line #278
# /home/rabreu/projeto_multimodal/data/balanced_train/video/290_SsB-AP-fcSY.mp4
# rownum = 290
# Labels = [2, 1]
# Processing Line #279
# /home/rabreu/projeto_multimodal/data/balanced_train/video/291_T1cYDKFI1is.mp4
# rownum = 291
# Labels = [2, 1]
# Processing Line #280
# /home/rabreu/projeto_multimodal/data/balanced_train/video/292_T8ohX1UzM7Q.mp4
# rownum = 292
# Labels = [6]
# Processing Line #281
# /home/rabreu/projeto_multimodal/data/balanced_train/video/293_TNK2G4wY46g.mp4
# rownum = 293
# Labels = [2, 1]
# Processing Line #282
# /home/rabreu/projeto_multimodal/data/balanced_train/video/294_TYoYRlICcZU.mp4
# rownum = 294
# Labels = [2, 1]
# Processing Line #283
# /home/rabreu/projeto_multimodal/data/balanced_train/video/295_TaamX_ehKnU.mp4
# rownum = 295
# Labels = [2, 1]
# Processing Line #284
# /home/rabreu/projeto_multimodal/data/balanced_train/video/296_TdDBJR2XKTA.mp4
# rownum = 296
# Labels = [5]
# Processing Line #285
# /home/rabreu/projeto_multimodal/data/balanced_train/video/297_TeA1puWNGgw.mp4
# rownum = 297
# Labels = [2]
# Processing Line #286
# /home/rabreu/projeto_multimodal/data/balanced_train/video/298_TvkwSM2RR4s.mp4
# rownum = 298
# Labels = [2, 1]
# Processing Line #287
# /home/rabreu/projeto_multimodal/data/balanced_train/video/299_U5dlogM7k9g.mp4
# rownum = 299
# Labels = [6]
# Processing Line #288
# /home/rabreu/projeto_multimodal/data/balanced_train/video/300_U8LvZzg_ruc.mp4
# rownum = 300
# Labels = [5]
# Processing Line #289
# /home/rabreu/projeto_multimodal/data/balanced_train/video/301_U8wU3xFj3TA.mp4
# rownum = 301
# Labels = [3]
# Processing Line #290
# /home/rabreu/projeto_multimodal/data/balanced_train/video/302_UCuylpOa2IE.mp4
# rownum = 302
# Labels = [1]
# Processing Line #291
# /home/rabreu/projeto_multimodal/data/balanced_train/video/303_UFAGCTDB7EY.mp4
# rownum = 303
# Labels = [6]
# Processing Line #292
# /home/rabreu/projeto_multimodal/data/balanced_train/video/305_UKMMD3z4qX4.mp4
# rownum = 305
# Labels = [2]
# Processing Line #293
# /home/rabreu/projeto_multimodal/data/balanced_train/video/306_ULFhHR0OLSE.mp4
# rownum = 306
# Labels = [4]
# Processing Line #294
# /home/rabreu/projeto_multimodal/data/balanced_train/video/307_UN84r_4GTdQ.mp4
# rownum = 307
# Labels = [2, 1]
# Processing Line #295
# /home/rabreu/projeto_multimodal/data/balanced_train/video/308_UOSl9vrp0Vs.mp4
# rownum = 308
# Labels = [0]
# Processing Line #296
# /home/rabreu/projeto_multimodal/data/balanced_train/video/309_Uj266NF1mUk.mp4
# rownum = 309
# Labels = [3]
# Processing Line #297
# /home/rabreu/projeto_multimodal/data/balanced_train/video/310_UmOOGxXbEuc.mp4
# rownum = 310
# Labels = [2]
# Processing Line #298
# /home/rabreu/projeto_multimodal/data/balanced_train/video/311_UrToRNte8cU.mp4
# rownum = 311
# Labels = [2, 1]
# Processing Line #299
# /home/rabreu/projeto_multimodal/data/balanced_train/video/314_VcQsSCgypQU.mp4
# rownum = 314
# Labels = [2]
# Processing Line #300
# /home/rabreu/projeto_multimodal/data/balanced_train/video/315_VzEmLYAcX_4.mp4
# rownum = 315
# Labels = [0]
# Processing Line #301
# /home/rabreu/projeto_multimodal/data/balanced_train/video/317_W6GWAWBuJFo.mp4
# rownum = 317
# Labels = [5]
# Processing Line #302
# /home/rabreu/projeto_multimodal/data/balanced_train/video/318_W7feeDJ8iNk.mp4
# rownum = 318
# Labels = [6]
# Processing Line #303
# /home/rabreu/projeto_multimodal/data/balanced_train/video/319_W8WFs-QDZnc.mp4
# rownum = 319
# Labels = [5]
# Processing Line #304
# /home/rabreu/projeto_multimodal/data/balanced_train/video/320_W8b5T4LJCOw.mp4
# rownum = 320
# Labels = [0, 3]
# Processing Line #305
# /home/rabreu/projeto_multimodal/data/balanced_train/video/321_WA49Qjw52lg.mp4
# rownum = 321
# Labels = [0]
# Processing Line #306
# /home/rabreu/projeto_multimodal/data/balanced_train/video/322_WdD4TtenRPA.mp4
# rownum = 322
# Labels = [2, 1]
# Processing Line #307
# /home/rabreu/projeto_multimodal/data/balanced_train/video/323_WoBYgyQqQKk.mp4
# rownum = 323
# Labels = [5]
# Processing Line #308
# /home/rabreu/projeto_multimodal/data/balanced_train/video/325_X2Urv2KkQqU.mp4
# rownum = 325
# Labels = [0, 3]
# Processing Line #309
# /home/rabreu/projeto_multimodal/data/balanced_train/video/326_X5s1jA9YJlo.mp4
# rownum = 326
# Labels = [0, 3]
# Processing Line #310
# /home/rabreu/projeto_multimodal/data/balanced_train/video/327_XREr4wTwG04.mp4
# rownum = 327
# Labels = [6]
# Processing Line #311
# /home/rabreu/projeto_multimodal/data/balanced_train/video/328_XVJvCtE1hEU.mp4
# rownum = 328
# Labels = [0, 3]
# Processing Line #312
# /home/rabreu/projeto_multimodal/data/balanced_train/video/329_Xazsdjxx8lM.mp4
# rownum = 329
# Labels = [6]
# Processing Line #313
# /home/rabreu/projeto_multimodal/data/balanced_train/video/330_XgLQ4gHHb8g.mp4
# rownum = 330
# Labels = [0, 3]
# Processing Line #314
# /home/rabreu/projeto_multimodal/data/balanced_train/video/331_Xoma_14dg08.mp4
# rownum = 331
# Labels = [6]
# Processing Line #315
# /home/rabreu/projeto_multimodal/data/balanced_train/video/332_Xug8OJNzEvI.mp4
# rownum = 332
# Labels = [1]
# Processing Line #316
# /home/rabreu/projeto_multimodal/data/balanced_train/video/333_Xy8fR4pJNmo.mp4
# rownum = 333
# Labels = [2, 1]
# Processing Line #317
# /home/rabreu/projeto_multimodal/data/balanced_train/video/334_Xyf_kzNG-iA.mp4
# rownum = 334
# Labels = [2]
# Processing Line #318
# /home/rabreu/projeto_multimodal/data/balanced_train/video/335_Y0Aibvz4GS0.mp4
# rownum = 335
# Labels = [3]
# Processing Line #319
# /home/rabreu/projeto_multimodal/data/balanced_train/video/336_YGYKAG2q19o.mp4
# rownum = 336
# Labels = [2]
# Processing Line #320
# /home/rabreu/projeto_multimodal/data/balanced_train/video/337_YHW0XmpLi2k.mp4
# rownum = 337
# Labels = [4, 0]
# Processing Line #321
# /home/rabreu/projeto_multimodal/data/balanced_train/video/338_YMrF9YkALDE.mp4
# rownum = 338
# Labels = [3]
# Processing Line #322
# /home/rabreu/projeto_multimodal/data/balanced_train/video/339_YhLgb_mzFbs.mp4
# rownum = 339
# Labels = [2]
# Processing Line #323
# /home/rabreu/projeto_multimodal/data/balanced_train/video/340_YqGivcrdNhw.mp4
# rownum = 340
# Labels = [2]
# Processing Line #324
# /home/rabreu/projeto_multimodal/data/balanced_train/video/341_YrCByX3Lm8Y.mp4
# rownum = 341
# Labels = [6]
# Processing Line #325
# /home/rabreu/projeto_multimodal/data/balanced_train/video/342_YvOAduVZfJE.mp4
# rownum = 342
# Labels = [6]
# Processing Line #326
# /home/rabreu/projeto_multimodal/data/balanced_train/video/343_YwdNnzWmiGc.mp4
# rownum = 343
# Labels = [2, 1]
# Processing Line #327
# /home/rabreu/projeto_multimodal/data/balanced_train/video/344_YxRbaNArrdA.mp4
# rownum = 344
# Labels = [6]
# Processing Line #328
# /home/rabreu/projeto_multimodal/data/balanced_train/video/345_Yxdd4q90B0E.mp4
# rownum = 345
# Labels = [6]
# Processing Line #329
# /home/rabreu/projeto_multimodal/data/balanced_train/video/346_Yxt9ASRCnaE.mp4
# rownum = 346
# Labels = [5]
# Processing Line #330
# /home/rabreu/projeto_multimodal/data/balanced_train/video/347_YyZkOm4Q9Is.mp4
# rownum = 347
# Labels = [5]
# Processing Line #331
# /home/rabreu/projeto_multimodal/data/balanced_train/video/348_Z-TXRCy2X3A.mp4
# rownum = 348
# Labels = [4]
# Processing Line #332
# /home/rabreu/projeto_multimodal/data/balanced_train/video/349_ZJC1zEC8G88.mp4
# rownum = 349
# Labels = [0]
# Processing Line #333
# /home/rabreu/projeto_multimodal/data/balanced_train/video/350_ZLX0rdNJsww.mp4
# rownum = 350
# Labels = [0, 3]
# Processing Line #334
# /home/rabreu/projeto_multimodal/data/balanced_train/video/351_ZM6krn037N4.mp4
# rownum = 351
# Labels = [2, 1]
# Processing Line #335
# /home/rabreu/projeto_multimodal/data/balanced_train/video/352_ZaeARmx4m0k.mp4
# rownum = 352
# Labels = [6]
# Processing Line #336
# /home/rabreu/projeto_multimodal/data/balanced_train/video/353_Zb10a9nW0ok.mp4
# rownum = 353
# Labels = [2]
# Processing Line #337
# /home/rabreu/projeto_multimodal/data/balanced_train/video/354_Zb_aIF1Wb44.mp4
# rownum = 354
# Labels = [0, 3]
# Processing Line #338
# /home/rabreu/projeto_multimodal/data/balanced_train/video/355_ZgaGheLPXys.mp4
# rownum = 355
# Labels = [5, 4]
# Processing Line #339
# /home/rabreu/projeto_multimodal/data/balanced_train/video/356_ZhEV3H3mCAg.mp4
# rownum = 356
# Labels = [4, 0]
# Processing Line #340
# /home/rabreu/projeto_multimodal/data/balanced_train/video/357_ZthT5nwFkJg.mp4
# rownum = 357
# Labels = [0, 3]
# Processing Line #341
# /home/rabreu/projeto_multimodal/data/balanced_train/video/358_ZuF8hkiuDRQ.mp4
# rownum = 358
# Labels = [5]
# Processing Line #342
# /home/rabreu/projeto_multimodal/data/balanced_train/video/359__0JKl45OmKY.mp4
# rownum = 359
# Labels = [2, 1]
# Processing Line #343
# /home/rabreu/projeto_multimodal/data/balanced_train/video/360__5x_-aTNCjU.mp4
# rownum = 360
# Labels = [0]
# Processing Line #344
# /home/rabreu/projeto_multimodal/data/balanced_train/video/361__76zOFOi7Xo.mp4
# rownum = 361
# Labels = [6]
# Processing Line #345
# /home/rabreu/projeto_multimodal/data/balanced_train/video/362__A4J2p4Dx6s.mp4
# rownum = 362
# Labels = [3]
# Processing Line #346
# /home/rabreu/projeto_multimodal/data/balanced_train/video/363__MXjq0eaIVk.mp4
# rownum = 363
# Labels = [3]
# Processing Line #347
# /home/rabreu/projeto_multimodal/data/balanced_train/video/364__RbYie-Fxo4.mp4
# rownum = 364
# Labels = [1]
# Processing Line #348
# /home/rabreu/projeto_multimodal/data/balanced_train/video/365__VKNhUxcvUw.mp4
# rownum = 365
# Labels = [4]
# Processing Line #349
# /home/rabreu/projeto_multimodal/data/balanced_train/video/366__lGsMYx8ezI.mp4
# rownum = 366
# Labels = [5]
# Processing Line #350
# /home/rabreu/projeto_multimodal/data/balanced_train/video/367__pelJnqTReE.mp4
# rownum = 367
# Labels = [2, 1]
# Processing Line #351
# /home/rabreu/projeto_multimodal/data/balanced_train/video/368__pgjMATDeSQ.mp4
# rownum = 368
# Labels = [6]
# Processing Line #352
# /home/rabreu/projeto_multimodal/data/balanced_train/video/369__s9WXTeZccA.mp4
# rownum = 369
# Labels = [3]
# Processing Line #353
# /home/rabreu/projeto_multimodal/data/balanced_train/video/371_a4nkA0NL4Hw.mp4
# rownum = 371
# Labels = [3]
# Processing Line #354
# /home/rabreu/projeto_multimodal/data/balanced_train/video/372_a6HE939n-Jk.mp4
# rownum = 372
# Labels = [2]
# Processing Line #355
# /home/rabreu/projeto_multimodal/data/balanced_train/video/373_aDMsH8STzE8.mp4
# rownum = 373
# Labels = [0]
# Processing Line #356
# /home/rabreu/projeto_multimodal/data/balanced_train/video/374_aLShWsDr7oQ.mp4
# rownum = 374
# Labels = [0]
# Processing Line #357
# /home/rabreu/projeto_multimodal/data/balanced_train/video/375_aMxLy5s3y8k.mp4
# rownum = 375
# Labels = [3]
# Processing Line #358
# /home/rabreu/projeto_multimodal/data/balanced_train/video/376_aVuoBwZxcJ4.mp4
# rownum = 376
# Labels = [2]
# Processing Line #359
# /home/rabreu/projeto_multimodal/data/balanced_train/video/378_apwQu55-5OI.mp4
# rownum = 378
# Labels = [5]
# Processing Line #360
# /home/rabreu/projeto_multimodal/data/balanced_train/video/380_b28rQfs-Z2w.mp4
# rownum = 380
# Labels = [6]
# Processing Line #361
# /home/rabreu/projeto_multimodal/data/balanced_train/video/381_bBdxLMRX5rs.mp4
# rownum = 381
# Labels = [6]
# Processing Line #362
# /home/rabreu/projeto_multimodal/data/balanced_train/video/382_bW_PMIAIHBE.mp4
# rownum = 382
# Labels = [3]
# Processing Line #363
# /home/rabreu/projeto_multimodal/data/balanced_train/video/383_brbEtmu2_MA.mp4
# rownum = 383
# Labels = [6]
# Processing Line #364
# /home/rabreu/projeto_multimodal/data/balanced_train/video/384_c65F3Bvn2y8.mp4
# rownum = 384
# Labels = [5]
# Processing Line #365
# /home/rabreu/projeto_multimodal/data/balanced_train/video/385_cEHnqMIacho.mp4
# rownum = 385
# Labels = [1]
# Processing Line #366
# /home/rabreu/projeto_multimodal/data/balanced_train/video/386_cKK0oZrwed8.mp4
# rownum = 386
# Labels = [2]
# Processing Line #367
# /home/rabreu/projeto_multimodal/data/balanced_train/video/387_cVxS2FAacrY.mp4
# rownum = 387
# Labels = [5]
# Processing Line #368
# /home/rabreu/projeto_multimodal/data/balanced_train/video/388_cYx-7UBAIZw.mp4
# rownum = 388
# Labels = [3]
# Processing Line #369
# /home/rabreu/projeto_multimodal/data/balanced_train/video/389_ci0SHipBCMs.mp4
# rownum = 389
# Labels = [0]
# Processing Line #370
# /home/rabreu/projeto_multimodal/data/balanced_train/video/390_cmllUfmgZsY.mp4
# rownum = 390
# Labels = [2]
# Processing Line #371
# /home/rabreu/projeto_multimodal/data/balanced_train/video/391_cwunY0NgTi4.mp4
# rownum = 391
# Labels = [0, 3]
# Processing Line #372
# /home/rabreu/projeto_multimodal/data/balanced_train/video/392_cz6oxIlmw_M.mp4
# rownum = 392
# Labels = [1]
# Processing Line #373
# /home/rabreu/projeto_multimodal/data/balanced_train/video/393_d5jxfxK6xUg.mp4
# rownum = 393
# Labels = [3]
# Processing Line #374
# /home/rabreu/projeto_multimodal/data/balanced_train/video/394_d61xTv_eJUw.mp4
# rownum = 394
# Labels = [2, 1]
# Processing Line #375
# /home/rabreu/projeto_multimodal/data/balanced_train/video/395_dI9HTTk6Mgs.mp4
# rownum = 395
# Labels = [3]
# Processing Line #376
# /home/rabreu/projeto_multimodal/data/balanced_train/video/396_dJudErPaMWI.mp4
# rownum = 396
# Labels = [4]
# Processing Line #377
# /home/rabreu/projeto_multimodal/data/balanced_train/video/397_dLEDy35kbEg.mp4
# rownum = 397
# Labels = [0]
# Processing Line #378
# /home/rabreu/projeto_multimodal/data/balanced_train/video/398_dM0bxfuu2eI.mp4
# rownum = 398
# Labels = [6]
# Processing Line #379
# /home/rabreu/projeto_multimodal/data/balanced_train/video/399_dQcv6M8mMGE.mp4
# rownum = 399
# Labels = [5]
# Processing Line #380
# /home/rabreu/projeto_multimodal/data/balanced_train/video/401_dqJWTzC3s8I.mp4
# rownum = 401
# Labels = [0, 3]
# Processing Line #381
# /home/rabreu/projeto_multimodal/data/balanced_train/video/402_dwP43cX6Ra4.mp4
# rownum = 402
# Labels = [1]
# Processing Line #382
# /home/rabreu/projeto_multimodal/data/balanced_train/video/403_dxcs_lpcwj0.mp4
# rownum = 403
# Labels = [5]
# Processing Line #383
# /home/rabreu/projeto_multimodal/data/balanced_train/video/404_eSI3y1oXXyw.mp4
# rownum = 404
# Labels = [6]
# Processing Line #384
# ...
# rownum = 448
# Labels = [0]
# Processing Line #426
# /home/rabreu/projeto_multimodal/data/balanced_train/video/449_jdiphmOtFVU.mp4
# rownum = 449
# Labels = [5]
# Processing Line #427
# /home/rabreu/projeto_multimodal/data/balanced_train/video/450_jjJgbpw0QmA.mp4
# rownum = 450
# Labels = [4, 0]
# Processing Line #428
# /home/rabreu/projeto_multimodal/data/balanced_train/video/451_jotE032i05c.mp4
# rownum = 451
# Labels = [6]
# Processing Line #429
# /home/rabreu/projeto_multimodal/data/balanced_train/video/452_jwbQ60-plVg.mp4
# rownum = 452
# Labels = [0, 3]
# Processing Line #430
# /home/rabreu/projeto_multimodal/data/balanced_train/video/453_k17Xq-wWn6w.mp4
# rownum = 453
# Labels = [6]
# Processing Line #431
# /home/rabreu/projeto_multimodal/data/balanced_train/video/454_kHlH-Ys2CSs.mp4
# rownum = 454
# Labels = [0, 3]
# Processing Line #432
# /home/rabreu/projeto_multimodal/data/balanced_train/video/455_kcnc66tQlxg.mp4
# rownum = 455
# Labels = [6]
# Processing Line #433
# /home/rabreu/projeto_multimodal/data/balanced_train/video/456_keDDfzMRHfg.mp4
# rownum = 456
# Labels = [3]
# Processing Line #434
# /home/rabreu/projeto_multimodal/data/balanced_train/video/457_kh2edY_BH2E.mp4
# rownum = 457
# Labels = [3]
# Processing Line #435
# /home/rabreu/projeto_multimodal/data/balanced_train/video/458_knn0QET_7DY.mp4
# rownum = 458
# Labels = [2]
# Processing Line #436
# /home/rabreu/projeto_multimodal/data/balanced_train/video/459_kseqhhdlsg0.mp4
# rownum = 459
# Labels = [0, 3]
# Processing Line #437
# /home/rabreu/projeto_multimodal/data/balanced_train/video/460_l21f-RphoQU.mp4
# rownum = 460
# Labels = [5]
# Processing Line #438
# /home/rabreu/projeto_multimodal/data/balanced_train/video/461_l4Z5jciACfM.mp4
# rownum = 461
# Labels = [2]
# Processing Line #439
# /home/rabreu/projeto_multimodal/data/balanced_train/video/462_l7mSUe1bxyE.mp4
# rownum = 462
# Labels = [5]
# Processing Line #440
# /home/rabreu/projeto_multimodal/data/balanced_train/video/463_lBnjix5PDHI.mp4
# rownum = 463
# Labels = [3]
# Processing Line #441
# /home/rabreu/projeto_multimodal/data/balanced_train/video/464_lNnj9q0oVLY.mp4
# rownum = 464
# Labels = [2]
# Processing Line #442
# /home/rabreu/projeto_multimodal/data/balanced_train/video/465_lWDYbFDhV8k.mp4
# rownum = 465
# Labels = [2]
# Processing Line #443
# /home/rabreu/projeto_multimodal/data/balanced_train/video/466_lmEiT0_7b0k.mp4
# rownum = 466
# Labels = [3]
# Processing Line #444
# /home/rabreu/projeto_multimodal/data/balanced_train/video/467_m3M8wMyXmUk.mp4
# rownum = 467
# Labels = [1]
# Processing Line #445
# /home/rabreu/projeto_multimodal/data/balanced_train/video/468_mIkW7mWlnXw.mp4
# rownum = 468
# Labels = [6]
# Processing Line #446
# /home/rabreu/projeto_multimodal/data/balanced_train/video/469_mi-s3pLeR3U.mp4
# rownum = 469
# Labels = [2, 1]
# Processing Line #447
# /home/rabreu/projeto_multimodal/data/balanced_train/video/470_mk3b2BgeyhA.mp4
# rownum = 470
# Labels = [2, 1]
# Processing Line #448
# /home/rabreu/projeto_multimodal/data/balanced_train/video/472_mmAigxjQbtE.mp4
# rownum = 472
# Labels = [6]
# Processing Line #449
# /home/rabreu/projeto_multimodal/data/balanced_train/video/473_mmFy-IgqOY8.mp4
# rownum = 473
# Labels = [4, 0]
# Processing Line #450
# /home/rabreu/projeto_multimodal/data/balanced_train/video/474_mpS0tUb_4q8.mp4
# rownum = 474
# Labels = [5]
# Processing Line #451
# /home/rabreu/projeto_multimodal/data/balanced_train/video/475_msZvt9_kbuU.mp4
# rownum = 475
# Labels = [5]
# Processing Line #452
# /home/rabreu/projeto_multimodal/data/balanced_train/video/476_mxgSJtIvyQg.mp4
# rownum = 476
# Labels = [5]
# Processing Line #453
# /home/rabreu/projeto_multimodal/data/balanced_train/video/477_my65DVXCPu4.mp4
# rownum = 477
# Labels = [5]
# Processing Line #454
# /home/rabreu/projeto_multimodal/data/balanced_train/video/478_nD_HctFk3Hc.mp4
# rownum = 478
# Labels = [6]
# Processing Line #455
# /home/rabreu/projeto_multimodal/data/balanced_train/video/480_ncmbVqH7rKE.mp4
# rownum = 480
# Labels = [0]
# Processing Line #456
# /home/rabreu/projeto_multimodal/data/balanced_train/video/481_neLgGXf0XJ4.mp4
# rownum = 481
# Labels = [6]
# Processing Line #457
# /home/rabreu/projeto_multimodal/data/balanced_train/video/482_nfhsxetUM5Q.mp4
# rownum = 482
# Labels = [0, 3]
# Processing Line #458
# /home/rabreu/projeto_multimodal/data/balanced_train/video/483_nhAismtQmkY.mp4
# rownum = 483
# Labels = [5]
# Processing Line #459
# /home/rabreu/projeto_multimodal/data/balanced_train/video/484_nuuykD2akvI.mp4
# rownum = 484
# Labels = [0]
# Processing Line #460
# /home/rabreu/projeto_multimodal/data/balanced_train/video/485_nyR4ONkiUaU.mp4
# rownum = 485
# Labels = [0, 3]
# Processing Line #461
# /home/rabreu/projeto_multimodal/data/balanced_train/video/486_nyoCE83Lg-c.mp4
# rownum = 486
# Labels = [0]
# Processing Line #462
# /home/rabreu/projeto_multimodal/data/balanced_train/video/487_o0-zzs1GDc4.mp4
# rownum = 487
# Labels = [0, 3]
# Processing Line #463
# /home/rabreu/projeto_multimodal/data/balanced_train/video/488_o4OMrBqHTRc.mp4
# rownum = 488
# Labels = [6]
# Processing Line #464
# /home/rabreu/projeto_multimodal/data/balanced_train/video/489_oTS4jW77rTQ.mp4
# rownum = 489
# Labels = [5]
# Processing Line #465
# /home/rabreu/projeto_multimodal/data/balanced_train/video/490_okXKlLF2lh0.mp4
# rownum = 490
# Labels = [6]
# Processing Line #466
# /home/rabreu/projeto_multimodal/data/balanced_train/video/491_okpTQM-Ft7A.mp4
# rownum = 491
# Labels = [0, 3]
# Processing Line #467
# /home/rabreu/projeto_multimodal/data/balanced_train/video/492_opnG6qoVYzM.mp4
# rownum = 492
# Labels = [5]
# Processing Line #468
# /home/rabreu/projeto_multimodal/data/balanced_train/video/493_pNTLvDgzQvM.mp4
# rownum = 493
# Labels = [6]
# Processing Line #469
# /home/rabreu/projeto_multimodal/data/balanced_train/video/494_pVwPoANEqgU.mp4
# rownum = 494
# Labels = [3]
# Processing Line #470
# /home/rabreu/projeto_multimodal/data/balanced_train/video/495_pZF-hff52ts.mp4
# rownum = 495
# Labels = [0, 3]
# Processing Line #471
# /home/rabreu/projeto_multimodal/data/balanced_train/video/496_paBYh4Sgs64.mp4
# rownum = 496
# Labels = [2, 1]
# Processing Line #472
# /home/rabreu/projeto_multimodal/data/balanced_train/video/497_peqGE-BKFb4.mp4
# rownum = 497
# Labels = [5]
# Processing Line #473
# /home/rabreu/projeto_multimodal/data/balanced_train/video/498_pfsF7y3fBgo.mp4
# rownum = 498
# Labels = [4, 0]
# Processing Line #474
# /home/rabreu/projeto_multimodal/data/balanced_train/video/499_pu0Xo4gjA7c.mp4
# rownum = 499
# Labels = [6]
# Processing Line #475
# /home/rabreu/projeto_multimodal/data/balanced_train/video/500_q-P6YlGm4uY.mp4
# rownum = 500
# Labels = [0, 3]
# Processing Line #476
# /home/rabreu/projeto_multimodal/data/balanced_train/video/501_q838lUfyL-E.mp4
# rownum = 501
# Labels = [2]
# Processing Line #477
# /home/rabreu/projeto_multimodal/data/balanced_train/video/502_qBLiT_0wwM4.mp4
# rownum = 502
# Labels = [2, 1]
# Processing Line #478
# /home/rabreu/projeto_multimodal/data/balanced_train/video/504_qQftDhgC51A.mp4
# rownum = 504
# Labels = [6]
# Processing Line #479
# /home/rabreu/projeto_multimodal/data/balanced_train/video/505_qSdPcsulqe4.mp4
# rownum = 505
# Labels = [5]
# Processing Line #480
# /home/rabreu/projeto_multimodal/data/balanced_train/video/506_qqMCiiZOaIA.mp4
# rownum = 506
# Labels = [5]
# Processing Line #481
# /home/rabreu/projeto_multimodal/data/balanced_train/video/508_qr7Z_1WM8pg.mp4
# rownum = 508
# Labels = [2]
# Processing Line #482
# /home/rabreu/projeto_multimodal/data/balanced_train/video/509_r3YX7kA3wB8.mp4
# rownum = 509
# Labels = [5]
# Processing Line #483
# /home/rabreu/projeto_multimodal/data/balanced_train/video/510_r5kMQR8qbcQ.mp4
# rownum = 510
# Labels = [5]
# Processing Line #484
# /home/rabreu/projeto_multimodal/data/balanced_train/video/511_rBdrfl0xivM.mp4
# rownum = 511
# Labels = [2]
# Processing Line #485
# /home/rabreu/projeto_multimodal/data/balanced_train/video/512_rHrpcMubkZ0.mp4
# rownum = 512
# Labels = [2]
# Processing Line #486
# /home/rabreu/projeto_multimodal/data/balanced_train/video/513_rK7LRuvEnHQ.mp4
# rownum = 513
# Labels = [6]
# Processing Line #487
# /home/rabreu/projeto_multimodal/data/balanced_train/video/514_rPH94rNhZl0.mp4
# rownum = 514
# Labels = [0, 3]
# Processing Line #488
# /home/rabreu/projeto_multimodal/data/balanced_train/video/515_rTaWJ4gZ7g0.mp4
# rownum = 515
# Labels = [2]
# Processing Line #489
# /home/rabreu/projeto_multimodal/data/balanced_train/video/516_roxImnh9YTI.mp4
# rownum = 516
# Labels = [6]
# Processing Line #490
# /home/rabreu/projeto_multimodal/data/balanced_train/video/517_rp3cD2jWlVE.mp4
# rownum = 517
# Labels = [6]
# Processing Line #491
# /home/rabreu/projeto_multimodal/data/balanced_train/video/518_rrGbQeCIQEc.mp4
# rownum = 518
# Labels = [4]
# Processing Line #492
# /home/rabreu/projeto_multimodal/data/balanced_train/video/519_ry4PXhwNgI4.mp4
# rownum = 519
# Labels = [4]
# Processing Line #493
# /home/rabreu/projeto_multimodal/data/balanced_train/video/520_s5JPbWkRXKs.mp4
# rownum = 520
# Labels = [5]
# Processing Line #494
# /home/rabreu/projeto_multimodal/data/balanced_train/video/521_s8uTcJJXmPM.mp4
# rownum = 521
# Labels = [2, 1]
# Processing Line #495
# /home/rabreu/projeto_multimodal/data/balanced_train/video/522_sA73ScSPS30.mp4
# rownum = 522
# Labels = [5]
# Processing Line #496
# /home/rabreu/projeto_multimodal/data/balanced_train/video/523_sVpj-evVHxs.mp4
# rownum = 523
# Labels = [2, 1]
# Processing Line #497
# /home/rabreu/projeto_multimodal/data/balanced_train/video/524_s_0sJckueug.mp4
# rownum = 524
# Labels = [5]
# Processing Line #498
# /home/rabreu/projeto_multimodal/data/balanced_train/video/525_scgXjJOykRA.mp4
# rownum = 525
# Labels = [6]
# Processing Line #499
# /home/rabreu/projeto_multimodal/data/balanced_train/video/526_sq3jcffMfwU.mp4
# rownum = 526
# Labels = [5]
# Processing Line #500
# /home/rabreu/projeto_multimodal/data/balanced_train/video/527_svGU7yB_AXw.mp4
# rownum = 527
# Labels = [4]
# Processing Line #501
# /home/rabreu/projeto_multimodal/data/balanced_train/video/528_t-OfBs9eVZ0.mp4
# rownum = 528
# Labels = [2, 1]
# Processing Line #502
# /home/rabreu/projeto_multimodal/data/balanced_train/video/529_tTtuoCraB1Y.mp4
# rownum = 529
# Labels = [3]
# Processing Line #503
# /home/rabreu/projeto_multimodal/data/balanced_train/video/530_tUIVZ_NR59k.mp4
# rownum = 530
# Labels = [6]
# Processing Line #504
# /home/rabreu/projeto_multimodal/data/balanced_train/video/531_tVZzdtnZaJk.mp4
# rownum = 531
# Labels = [2, 1]
# Processing Line #505
# /home/rabreu/projeto_multimodal/data/balanced_train/video/532_tY0blkKvjPg.mp4
# rownum = 532
# Labels = [6]
# Processing Line #506
# /home/rabreu/projeto_multimodal/data/balanced_train/video/533_t_zbXrKUDEE.mp4
# rownum = 533
# Labels = [6]
# Processing Line #507
# /home/rabreu/projeto_multimodal/data/balanced_train/video/534_toDcLiHJUEA.mp4
# rownum = 534
# Labels = [3]
# Processing Line #508
# /home/rabreu/projeto_multimodal/data/balanced_train/video/535_ttCOebeJ59A.mp4
# rownum = 535
# Labels = [4]
# Processing Line #509
# /home/rabreu/projeto_multimodal/data/balanced_train/video/536_tuZYdoic2lk.mp4
# rownum = 536
# Labels = [4, 0]
# Processing Line #510
# /home/rabreu/projeto_multimodal/data/balanced_train/video/537_tulo2-_Gmhg.mp4
# rownum = 537
# Labels = [2]
# Processing Line #511
# /home/rabreu/projeto_multimodal/data/balanced_train/video/538_u7KaWl9PTo0.mp4
# rownum = 538
# Labels = [5]
# Processing Line #512
# /home/rabreu/projeto_multimodal/data/balanced_train/video/539_uCm-Rsvrw0s.mp4
# rownum = 539
# Labels = [3]
# Processing Line #513
# /home/rabreu/projeto_multimodal/data/balanced_train/video/540_uLETIQnJM44.mp4
# rownum = 540
# Labels = [6]
# Processing Line #514
# /home/rabreu/projeto_multimodal/data/balanced_train/video/541_uLQPPdAKp1w.mp4
# rownum = 541
# Labels = [4, 0]
# Processing Line #515
# /home/rabreu/projeto_multimodal/data/balanced_train/video/542_uUSsG40KbhM.mp4
# rownum = 542
# Labels = [6]
# Processing Line #516
# /home/rabreu/projeto_multimodal/data/balanced_train/video/543_u_KQFX8hZyk.mp4
# rownum = 543
# Labels = [2]
# Processing Line #517
# /home/rabreu/projeto_multimodal/data/balanced_train/video/544_ucJC2w8dLg4.mp4
# rownum = 544
# Labels = [2]
# Processing Line #518
# /home/rabreu/projeto_multimodal/data/balanced_train/video/545_ukO-_sq-u6U.mp4
# rownum = 545
# Labels = [4]
# Processing Line #519
# /home/rabreu/projeto_multimodal/data/balanced_train/video/546_upxh7mZ5IBo.mp4
# rownum = 546
# Labels = [3]
# Processing Line #520
# /home/rabreu/projeto_multimodal/data/balanced_train/video/547_uqtwOTsOF7I.mp4
# rownum = 547
# Labels = [5]
# Processing Line #521
# /home/rabreu/projeto_multimodal/data/balanced_train/video/548_v56paXFFfig.mp4
# rownum = 548
# Labels = [4]
# Processing Line #522
# /home/rabreu/projeto_multimodal/data/balanced_train/video/549_vHHcJ6fcKEI.mp4
# rownum = 549
# Labels = [6]
# Processing Line #523
# /home/rabreu/projeto_multimodal/data/balanced_train/video/550_vJwCeEoc6Ss.mp4
# rownum = 550
# Labels = [5]
# Processing Line #524
# /home/rabreu/projeto_multimodal/data/balanced_train/video/551_vQWFMfbDJyI.mp4
# rownum = 551
# Labels = [2, 1]
# Processing Line #525
# /home/rabreu/projeto_multimodal/data/balanced_train/video/552_vQdYJv4Mebk.mp4
# rownum = 552
# Labels = [6]
# Processing Line #526
# /home/rabreu/projeto_multimodal/data/balanced_train/video/553_vXOhbFavtqU.mp4
# rownum = 553
# Labels = [0]
# Processing Line #527
# /home/rabreu/projeto_multimodal/data/balanced_train/video/554_vXOwQ7_5f3M.mp4
# rownum = 554
# Labels = [6]
# Processing Line #528
# /home/rabreu/projeto_multimodal/data/balanced_train/video/555_vcmuZ3MDSK8.mp4
# rownum = 555
# Labels = [0, 3]
# Processing Line #529
# /home/rabreu/projeto_multimodal/data/balanced_train/video/556_vmCvyAgLJWc.mp4
# rownum = 556
# Labels = [3]
# Processing Line #530
# /home/rabreu/projeto_multimodal/data/balanced_train/video/557_vwqISkG7o50.mp4
# rownum = 557
# Labels = [6]
# Processing Line #531
# /home/rabreu/projeto_multimodal/data/balanced_train/video/559_w82xpBR_Z4A.mp4
# rownum = 559
# Labels = [5]
# Processing Line #532
# /home/rabreu/projeto_multimodal/data/balanced_train/video/560_wRO3h_zt1b4.mp4
# rownum = 560
# Labels = [5]
# Processing Line #533
# /home/rabreu/projeto_multimodal/data/balanced_train/video/561_wRVZAD1pfeo.mp4
# rownum = 561
# Labels = [0, 3]
# Processing Line #534
# /home/rabreu/projeto_multimodal/data/balanced_train/video/562_wdVYP2ijnew.mp4
# rownum = 562
# Labels = [0, 3]
# Processing Line #535
# /home/rabreu/projeto_multimodal/data/balanced_train/video/563_woVeO6XRBEY.mp4
# rownum = 563
# Labels = [1]
# Processing Line #536
# /home/rabreu/projeto_multimodal/data/balanced_train/video/564_wtA8A8_jBo4.mp4
# rownum = 564
# Labels = [6]
# Processing Line #537
# /home/rabreu/projeto_multimodal/data/balanced_train/video/565_xFzsYFhrHtk.mp4
# rownum = 565
# Labels = [2]
# Processing Line #538
# /home/rabreu/projeto_multimodal/data/balanced_train/video/566_xOUZBQdeXGc.mp4
# rownum = 566
# Labels = [0]
# Processing Line #539
# /home/rabreu/projeto_multimodal/data/balanced_train/video/567_xWfYh7-y7CA.mp4
# rownum = 567
# Labels = [2]
# Processing Line #540
# /home/rabreu/projeto_multimodal/data/balanced_train/video/569_y2A1Pmiu7yw.mp4
# rownum = 569
# Labels = [2]
# Processing Line #541
# /home/rabreu/projeto_multimodal/data/balanced_train/video/570_yA_HhB94RK0.mp4
# rownum = 570
# Labels = [2, 1]
# Processing Line #542
# /home/rabreu/projeto_multimodal/data/balanced_train/video/571_yFmmu6irQrk.mp4
# rownum = 571
# Labels = [4]
# Processing Line #543
# /home/rabreu/projeto_multimodal/data/balanced_train/video/572_yYqURVoqlXw.mp4
# rownum = 572
# Labels = [3]
# Processing Line #544
# /home/rabreu/projeto_multimodal/data/balanced_train/video/573_yx-gN-b5yLY.mp4
# rownum = 573
# Labels = [2, 1]
# Processing Line #545
# /home/rabreu/projeto_multimodal/data/balanced_train/video/575_zC3MxGNQ4fY.mp4
# rownum = 575
# Labels = [2, 1]
# Processing Line #546
# /home/rabreu/projeto_multimodal/data/balanced_train/video/576_zF_DBcU9p4U.mp4
# rownum = 576
# Labels = [6]
# Processing Line #547
# /home/rabreu/projeto_multimodal/data/balanced_train/video/577_zHy43cBfK9M.mp4
# rownum = 577
# Labels = [0, 3]
# Processing Line #548
# /home/rabreu/projeto_multimodal/data/balanced_train/video/578_zIp0QqCfYAE.mp4
# rownum = 578
# Labels = [2]
# Processing Line #549
# /home/rabreu/projeto_multimodal/data/balanced_train/video/579_zNswU3Pmyn0.mp4
# rownum = 579
# Labels = [6]
# Processing Line #550
# /home/rabreu/projeto_multimodal/data/balanced_train/video/580_zlt89JkjR8c.mp4
# rownum = 580
# Labels = [5]
# Processing Line #551
# /home/rabreu/projeto_multimodal/data/balanced_train/video/581_zu53y8M2xBc.mp4
# rownum = 581
# Labels = [0]
# Features of =  (552, 32, 32, 32, 3)
# Labels of =  (552, 7)

# %%
## só use este pedaço de código para salvar os dados. Caso tenha salvo pode pular ele

features, labels = parse_video_files(data_dir,train_sub_dir,audioset_train_csv,file_ext='*.mp4')
save_dir = data_dir+train_sub_dir+"/2000features/"
assure_path_exists(save_dir)
save_files(save_dir,features,labels)

print(data_dir+eval_sub_dir)
features, labels = parse_video_files(data_dir,eval_sub_dir,audioset_eval_csv,file_ext='*.mp4')
save_dir = data_dir+eval_sub_dir+"/2000features/"
assure_path_exists(save_dir)
save_files(save_dir,features,labels)
# Out:
# rownum = 11096
# Labels = [4, 0]
# Processing Line #10542
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11097_41CLCpc_ArA.mp4
# rownum = 11097
# Labels = [2]
# Processing Line #10543
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11099_O8IU8-J2MqU.mp4
# rownum = 11099
# Labels = [6]
# Processing Line #10544
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11100_BBGviiH1SOg.mp4
# rownum = 11100
# Labels = [5]
# Processing Line #10545
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11101_E5q5_xfHdDw.mp4
# rownum = 11101
# Labels = [3]
# Processing Line #10546
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11102_4EBk8FCpQh4.mp4
# rownum = 11102
# Labels = [6]
# Processing Line #10547
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11103_23wtCcm4iWQ.mp4
# rownum = 11103
# Labels = [2]
# Processing Line #10548
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11104_Cqe8eKxekgk.mp4
# rownum = 11104
# Labels = [6]
# Processing Line #10549
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11105_4sMmtEskIVM.mp4
# rownum = 11105
# Labels = [5]
# Processing Line #10550
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11106_qgQBGNhLKR8.mp4
# rownum = 11106
# Labels = [1]
# Processing Line #10551
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11107_omlewrRvQXA.mp4
# rownum = 11107
# Labels = [4]
# Processing Line #10552
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11108_h7JswUS3ubc.mp4
# rownum = 11108
# Labels = [2, 1]
# Processing Line #10553
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11109_D7CfFgIpHD8.mp4
# rownum = 11109
# Labels = [6]
# Processing Line #10554
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11110_7R5CAB0riL4.mp4
# rownum = 11110
# Labels = [2]
# Processing Line #10555
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11111_AU4zmsbbguc.mp4
# rownum = 11111
# Labels = [0]
# Processing Line #10556
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11112_UCTAsp2AFzg.mp4
# rownum = 11112
# Labels = [1]
# Processing Line #10557
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11113_0jZYjTCvxp4.mp4
# rownum = 11113
# Labels = [4]
# Processing Line #10558
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11114_Pv2dkWcqjiQ.mp4
# rownum = 11114
# Labels = [0, 3]
# Processing Line #10559
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11115_9wLvIJvmpOw.mp4
# rownum = 11115
# Labels = [0]
# Processing Line #10560
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11116_10lYkh-LDpI.mp4
# rownum = 11116
# Labels = [0]
# Processing Line #10561
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11117_0yk7tkX9mOY.mp4
# rownum = 11117
# Labels = [0]
# Processing Line #10562
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11118_DOFRAZOtk4E.mp4
# rownum = 11118
# Labels = [2]
# Processing Line #10563
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11119_AdV3t1O_4GA.mp4
# rownum = 11119
# Labels = [0]
# Processing Line #10564
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11120_UQomAF34Wgg.mp4
# rownum = 11120
# Labels = [0, 3]
# Processing Line #10565
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11121_Q98aLECPmGY.mp4
# rownum = 11121
# Labels = [6]
# Processing Line #10566
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11122_YEaVdduZVPc.mp4
# rownum = 11122
# Labels = [0, 3]
# Processing Line #10567
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11123_-aN6_aAQUDQ.mp4
# rownum = 11123
# Labels = [0]
# Processing Line #10568
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11124_4BCljSZXmSQ.mp4
# rownum = 11124
# Labels = [6]
# Processing Line #10569
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11125_6g72EGL2qK8.mp4
# rownum = 11125
# Labels = [2]
# Processing Line #10570
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11126_dU0kikYV5e8.mp4
# rownum = 11126
# Labels = [4]
# Processing Line #10571
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11127_-pS1iVTSpmU.mp4
# rownum = 11127
# Labels = [5]
# Processing Line #10572
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11128_TUes4HKqvKc.mp4
# rownum = 11128
# Labels = [5]
# Processing Line #10573
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11129_TpD63r7K0Ig.mp4
# rownum = 11129
# Labels = [6]
# Processing Line #10574
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11130_ydc0oG9pC7k.mp4
# rownum = 11130
# Labels = [2, 1]
# Processing Line #10575
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11131_H5XOSOQWfW0.mp4
# rownum = 11131
# Labels = [5]
# Processing Line #10576
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11132_Ix0DkoaDvUI.mp4
# rownum = 11132
# Labels = [6]
# Processing Line #10577
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11133_DOhveFXypr8.mp4
# rownum = 11133
# Labels = [0]
# Processing Line #10578
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11134_NKe0GaCbLYQ.mp4
# rownum = 11134
# Labels = [6]
# Processing Line #10579
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11135_BIHYNTH5lBE.mp4
# rownum = 11135
# Labels = [0]
# Processing Line #10580
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11136_Aws-stDmiqo.mp4
# rownum = 11136
# Labels = [5]
# Processing Line #10581
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11137_SDvsElJrCa0.mp4
# rownum = 11137
# Labels = [0, 3]
# Processing Line #10582
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11138_6emjoGz1ddU.mp4
# rownum = 11138
# Labels = [6]
# Processing Line #10583
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11140_CA4LpTlRPCo.mp4
# rownum = 11140
# Labels = [6]
# Processing Line #10584
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11141_6fyiIOmGNf4.mp4
# rownum = 11141
# Labels = [0]
# Processing Line #10585
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11143_EVYhcop992w.mp4
# rownum = 11143
# Labels = [3]
# Processing Line #10586
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11144_0ExdbGAMUb8.mp4
# rownum = 11144
# Labels = [0]
# Processing Line #10587
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11145_7vE3unkkaVA.mp4
# rownum = 11145
# Labels = [2]
# Processing Line #10588
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11146_eAb-9fiVEys.mp4
# rownum = 11146
# Labels = [5]
# Processing Line #10589
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11147_8aAJgB4xAIw.mp4
# rownum = 11147
# Labels = [3]
# Processing Line #10590
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11148_tTwtXMveoPY.mp4
# rownum = 11148
# Labels = [4, 0]
# Processing Line #10591
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11149_d_LQg44-8Nc.mp4
# rownum = 11149
# Labels = [4]
# Processing Line #10592
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11150_2u4iFJod-qo.mp4
# rownum = 11150
# Labels = [2]
# Processing Line #10593
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11151_3GZAZKRB2hM.mp4
# rownum = 11151
# Labels = [4]
# Processing Line #10594
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11152_PyEPoADWTw0.mp4
# rownum = 11152
# Labels = [0, 3]
# Processing Line #10595
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11153_6GKadxwgS60.mp4
# rownum = 11153
# Labels = [5]
# Processing Line #10596
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11154_sUVUOiVRLDY.mp4
# rownum = 11154
# Labels = [4]
# Processing Line #10597
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11155_2d3zaAtNfIA.mp4
# rownum = 11155
# Labels = [0]
# Processing Line #10598
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11156_1SJi-jQf_2s.mp4
# rownum = 11156
# Labels = [2]
# Processing Line #10599
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11157_RtCQilL8Xb0.mp4
# rownum = 11157
# Labels = [0, 3]
# Processing Line #10600
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11158_5c8IEB9YaLQ.mp4
# rownum = 11158
# Labels = [2]
# Processing Line #10601
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11159_639mzYB86gs.mp4
# rownum = 11159
# Labels = [5]
# Processing Line #10602
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11161_KyM6CbsHvBw.mp4
# rownum = 11161
# Labels = [6]
# Processing Line #10603
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11162_0osbTRipbhw.mp4
# rownum = 11162
# Labels = [3]
# Processing Line #10604
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11163_FN7jKFqECU0.mp4
# rownum = 11163
# Labels = [5]
# Processing Line #10605
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11164_2pVR0O_MeBM.mp4
# rownum = 11164
# Labels = [0]
# Processing Line #10606
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11165_Isu5g1FxlQo.mp4
# rownum = 11165
# Labels = [4, 0]
# Processing Line #10607
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11166_MaGnl5rdw6I.mp4
# rownum = 11166
# Labels = [1]
# Processing Line #10608
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11167_2NOBkkK56wA.mp4
# rownum = 11167
# Labels = [2]
# Processing Line #10609
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11168_D7IcwDi1TRI.mp4
# rownum = 11168
# Labels = [6]
# Processing Line #10610
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11169__8fCdExID8Q.mp4
# rownum = 11169
# Labels = [4]
# Processing Line #10611
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11170_lFhFj-CHHgs.mp4
# rownum = 11170
# Labels = [1]
# Processing Line #10612
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11171_9kkR8w0LITQ.mp4
# rownum = 11171
# Labels = [6]
# Processing Line #10613
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11172_pSicNCPF3b0.mp4
# rownum = 11172
# Labels = [4]
# Processing Line #10614
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11173_GLMsJp_CpyI.mp4
# rownum = 11173
# Labels = [5]
# Processing Line #10615
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11174_-hBmk06gwd8.mp4
# rownum = 11174
# Labels = [3]
# Processing Line #10616
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11175_DuDzl9dERbM.mp4
# rownum = 11175
# Labels = [0]
# Processing Line #10617
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11176_Jk4jwKSY_4k.mp4
# rownum = 11176
# Labels = [2]
# Processing Line #10618
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11177_8-hCWXKfUlA.mp4
# rownum = 11177
# Labels = [3]
# Processing Line #10619
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11178_9FDW4-Tb_EI.mp4
# rownum = 11178
# Labels = [4]
# Processing Line #10620
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11179_B7n3d7hNnfA.mp4
# rownum = 11179
# Labels = [2]
# Processing Line #10621
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11180_8RUzs8o_gaI.mp4
# rownum = 11180
# Labels = [2]
# Processing Line #10622
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11181_PW432Yx9_j4.mp4
# rownum = 11181
# Labels = [5]
# Processing Line #10623
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11182_-FLbNcUhBsY.mp4
# rownum = 11182
# Labels = [2]
# Processing Line #10624
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11183_4dpQLCHPjHY.mp4
# rownum = 11183
# Labels = [0]
# Processing Line #10625
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11184_0MJAFpTRZAw.mp4
# rownum = 11184
# Labels = [6]
# Processing Line #10626
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11185_E0dyx6hifaA.mp4
# rownum = 11185
# Labels = [5]
# Processing Line #10627
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11186_1q30rbEIL40.mp4
# rownum = 11186
# Labels = [2]
# Processing Line #10628
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11187_NKi9GKh9x2s.mp4
# rownum = 11187
# Labels = [5]
# Processing Line #10629
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11188_TuAQ-H-bal0.mp4
# rownum = 11188
# Labels = [6]
# Processing Line #10630
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11189_-nBBzEXQ4Jg.mp4
# rownum = 11189
# Labels = [3]
# Processing Line #10631
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11190_ElltBvgcZuI.mp4
# rownum = 11190
# Labels = [0]
# Processing Line #10632
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11191_1N8cmXJeOdw.mp4
# rownum = 11191
# Labels = [6]
# Processing Line #10633
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11192_4NPKvS5UPPY.mp4
# rownum = 11192
# Labels = [3]
# Processing Line #10634
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11193_KzxzfRWBVbY.mp4
# rownum = 11193
# Labels = [5]
# Processing Line #10635
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11194_NXiODwpltLs.mp4
# rownum = 11194
# Labels = [4]
# Processing Line #10636
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11195_1ni3AC2Yux4.mp4
# rownum = 11195
# Labels = [5]
# Processing Line #10637
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11196_7rboBCQyu_U.mp4
# rownum = 11196
# Labels = [5]
# Processing Line #10638
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11197_Pge0T-z0c0o.mp4
# rownum = 11197
# Labels = [1]
# Processing Line #10639
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11198_aEsR98tN_sg.mp4
# rownum = 11198
# Labels = [5]
# Processing Line #10640
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11199_9HVnVotaTdY.mp4
# rownum = 11199
# Labels = [5]
# Processing Line #10641
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11200_7Cnhf6ii9BI.mp4
# rownum = 11200
# Labels = [4]
# Processing Line #10642
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11201_4_gwgzMS-KA.mp4
# rownum = 11201
# Labels = [0]
# Processing Line #10643
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11202_3YTg2sHUvwE.mp4
# rownum = 11202
# Labels = [2]
# Processing Line #10644
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11203_CHYx1fe5yO8.mp4
# rownum = 11203
# Labels = [5]
# Processing Line #10645
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11204_F7n6PiYC8nY.mp4
# rownum = 11204
# Labels = [2]
# Processing Line #10646
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11205_0-6AL5yJbrc.mp4
# rownum = 11205
# Labels = [6]
# Processing Line #10647
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11206_13gko4-3PzY.mp4
# rownum = 11206
# Labels = [5]
# Processing Line #10648
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11207_NRYDoi0mjwo.mp4
# rownum = 11207
# Labels = [5]
# Processing Line #10649
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11208_d-5WQbx-dzA.mp4
# rownum = 11208
# Labels = [5]
# Processing Line #10650
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11209_CsR3vW2BZiY.mp4
# rownum = 11209
# Labels = [2]
# Processing Line #10651
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11210_7MlnPrY145E.mp4
# rownum = 11210
# Labels = [0]
# Processing Line #10652
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11211_PlFUVopd-bg.mp4
# rownum = 11211
# Labels = [3]
# Processing Line #10653
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11212_ZFroMaeeC-o.mp4
# rownum = 11212
# Labels = [0, 3]
# Processing Line #10654
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11213_0tQRmnN4qfY.mp4
# rownum = 11213
# Labels = [0]
# Processing Line #10655
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11214_TdluICnt_fU.mp4
# rownum = 11214
# Labels = [5]
# Processing Line #10656
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11215_DvMFQ64YwcI.mp4
# rownum = 11215
# Labels = [0]
# Processing Line #10657
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11216_0TQmkmGdFdk.mp4
# rownum = 11216
# Labels = [0]
# Processing Line #10658
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11217_c202jWfndyI.mp4
# rownum = 11217
# Labels = [1]
# Processing Line #10659
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11218_8N4KO96rkdU.mp4
# rownum = 11218
# Labels = [0]
# Processing Line #10660
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11219_0KRskefPYuM.mp4
# rownum = 11219
# Labels = [2]
# Processing Line #10661
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11220_C6DQgxgrz_U.mp4
# rownum = 11220
# Labels = [0]
# Processing Line #10662
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11221_Rd3pFQoJW9k.mp4
# rownum = 11221
# Labels = [2]
# Processing Line #10663
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11222_OY_M8tmQjfg.mp4
# rownum = 11222
# Labels = [0, 3]
# Processing Line #10664
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11223_0Stq3XQqmYE.mp4
# rownum = 11223
# Labels = [6]
# Processing Line #10665
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11224_9Uk8z4598ho.mp4
# rownum = 11224
# Labels = [2]
# Processing Line #10666
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11225_AFBJ5Eh7Drc.mp4
# rownum = 11225
# Labels = [6]
# Processing Line #10667
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11226_83HZPiAk_Oc.mp4
# rownum = 11226
# Labels = [6]
# Processing Line #10668
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11227_Q8D-OGbwoaA.mp4
# rownum = 11227
# Labels = [0, 3]
# Processing Line #10669
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11228_IE9U_E6-9mE.mp4
# rownum = 11228
# Labels = [3]
# Processing Line #10670
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11229_tpcV94PMNWo.mp4
# rownum = 11229
# Labels = [4]
# Processing Line #10671
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11230_8HVHe_rP-Oo.mp4
# rownum = 11230
# Labels = [3]
# Processing Line #10672
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11231_5LzxmTUpgMI.mp4
# rownum = 11231
# Labels = [0]
# Processing Line #10673
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11232_DXKQ-NQBCaI.mp4
# rownum = 11232
# Labels = [0]
# Processing Line #10674
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11233_SWv7YZnOYz0.mp4
# rownum = 11233
# Labels = [5]
# Processing Line #10675
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11234_8cVtW6V-GDs.mp4
# rownum = 11234
# Labels = [3]
# Processing Line #10676
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11235_DV4_4JgOmI0.mp4
# rownum = 11235
# Labels = [4]
# Processing Line #10677
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11236_52oxIyimcp0.mp4
# rownum = 11236
# Labels = [0]
# Processing Line #10678
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11237_ToyUXQKrhLE.mp4
# rownum = 11237
# Labels = [6]
# Processing Line #10679
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11238_OI5FodTedic.mp4
# rownum = 11238
# Labels = [0, 1]
# Processing Line #10680
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11239_FXs4e1eYDY8.mp4
# rownum = 11239
# Labels = [6]
# Processing Line #10681
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11240_6Kivf401AFM.mp4
# rownum = 11240
# Labels = [0]
# Processing Line #10682
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11241_5tAQweacu1Q.mp4
# rownum = 11241
# Labels = [6]
# Processing Line #10683
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11242_ABTJSxJI3Z8.mp4
# rownum = 11242
# Labels = [6]
# Processing Line #10684
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11243_h_AaexPNN8Y.mp4
# rownum = 11243
# Labels = [1]
# Processing Line #10685
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11244_BQtODnK2gLg.mp4
# rownum = 11244
# Labels = [0]
# Processing Line #10686
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11245_5ZYM9JLP6g8.mp4
# rownum = 11245
# Labels = [5]
# Processing Line #10687
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11246_h3UhoHIMfpw.mp4
# rownum = 11246
# Labels = [4, 0]
# Processing Line #10688
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11247_d0n8dpb7Vvk.mp4
# rownum = 11247
# Labels = [5]
# Processing Line #10689
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11248_IB0gpjmsRDk.mp4
# rownum = 11248
# Labels = [6]
# Processing Line #10690
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11249_AxA1M-4APsI.mp4
# rownum = 11249
# Labels = [0]
# Processing Line #10691
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11250_6Zdr8ZyM0fs.mp4
# rownum = 11250
# Labels = [2]
# Processing Line #10692
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11251_cPiSd5nJLrI.mp4
# rownum = 11251
# Labels = [5]
# Processing Line #10693
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11252_TDsP__WV5og.mp4
# rownum = 11252
# Labels = [5]
# Processing Line #10694
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11253_-DN0XLqlVSs.mp4
# rownum = 11253
# Labels = [0]
# Processing Line #10695
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11254_stTTtm7ggWo.mp4
# rownum = 11254
# Labels = [4]
# Processing Line #10696
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11255_-RNPQI3AJMw.mp4
# rownum = 11255
# Labels = [6]
# Processing Line #10697
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11256_59GanQ6Xabg.mp4
# rownum = 11256
# Labels = [0]
# Processing Line #10698
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11257_20Zl8_jokG8.mp4
# rownum = 11257
# Labels = [0]
# Processing Line #10699
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11258_LR1CRnp42nw.mp4
# rownum = 11258
# Labels = [5]
# Processing Line #10700
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11259_aq_Awi0xE_c.mp4
# rownum = 11259
# Labels = [5]
# Processing Line #10701
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11260_i5ZpKMqaweo.mp4
# rownum = 11260
# Labels = [1]
# Processing Line #10702
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11261_SAvvVd6UbRA.mp4
# rownum = 11261
# Labels = [3]
# Processing Line #10703
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11262_CEgyXSAygiw.mp4
# rownum = 11262
# Labels = [5]
# Processing Line #10704
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11263_UcnJvrgMCH4.mp4
# rownum = 11263
# Labels = [5]
# Processing Line #10705
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11265_GbM3QFssUhM.mp4
# rownum = 11265
# Labels = [3]
# Processing Line #10706
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11266_2VDyWTKKKTs.mp4
# rownum = 11266
# Labels = [2]
# Processing Line #10707
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11267_2wNUBJxV8Ec.mp4
# rownum = 11267
# Labels = [0]
# Processing Line #10708
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11268_KbnM1QpuwWI.mp4
# rownum = 11268
# Labels = [5]
# Processing Line #10709
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11269_bsHTiVZS_QY.mp4
# rownum = 11269
# Labels = [5]
# Processing Line #10710
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11270_3Vn45ZJ1iOA.mp4
# rownum = 11270
# Labels = [6]
# Processing Line #10711
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11271_RKq8KfaKeP4.mp4
# rownum = 11271
# Labels = [2]
# Processing Line #10712
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11272_M6c-R4Wlz4Y.mp4
# rownum = 11272
# Labels = [5]
# Processing Line #10713
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11273_EnCx27bUerY.mp4
# rownum = 11273
# Labels = [2]
# Processing Line #10714
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11274_KNi3fiTCE4g.mp4
# rownum = 11274
# Labels = [0, 3]
# Processing Line #10715
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11275_DEBQP_oG8y0.mp4
# rownum = 11275
# Labels = [6]
# Processing Line #10716
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11276_7YKROGEFq4w.mp4
# rownum = 11276
# Labels = [0]
# Processing Line #10717
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11277_CU2U5QORnFU.mp4
# rownum = 11277
# Labels = [5]
# Processing Line #10718
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11278_-u90KJp3FFM.mp4
# rownum = 11278
# Labels = [5]
# Processing Line #10719
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11279_nmxf3LrNqNk.mp4
# rownum = 11279
# Labels = [4]
# Processing Line #10720
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11280_IlxWQBPZ5uI.mp4
# rownum = 11280
# Labels = [6]
# Processing Line #10721
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11281_9BxhtztaAdM.mp4
# rownum = 11281
# Labels = [4]
# Processing Line #10722
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11282_2YcWc3Iwp4Y.mp4
# rownum = 11282
# Labels = [5]
# Processing Line #10723
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11283_8naZD_JdWYY.mp4
# rownum = 11283
# Labels = [6]
# Processing Line #10724
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11284_LAwkfMLLh4A.mp4
# rownum = 11284
# Labels = [2]
# Processing Line #10725
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11285_J8eVYy5q4QY.mp4
# rownum = 11285
# Labels = [5]
# Processing Line #10726
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11286_RZSrIe9CrLM.mp4
# rownum = 11286
# Labels = [6]
# Processing Line #10727
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11287_PpBND1lWEZk.mp4
# rownum = 11287
# Labels = [6]
# Processing Line #10728
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11288_EccgQj1WV6M.mp4
# rownum = 11288
# Labels = [2]
# Processing Line #10729
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11289_SllQ8m6NjBs.mp4
# rownum = 11289
# Labels = [4]
# Processing Line #10730
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11290_D_j2VXxbojY.mp4
# rownum = 11290
# Labels = [0]
# Processing Line #10731
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11291_NHic3_6KYfM.mp4
# rownum = 11291
# Labels = [6]
# Processing Line #10732
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11292_YPmn1rxyU8g.mp4
# rownum = 11292
# Labels = [2]
# Processing Line #10733
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11293_4NTiIPWRufA.mp4
# rownum = 11293
# Labels = [0]
# Processing Line #10734
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11294_K9kTWqVtAH0.mp4
# rownum = 11294
# Labels = [6]
# Processing Line #10735
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11295_PxlZPEHZRGo.mp4
# rownum = 11295
# Labels = [6]
# Processing Line #10736
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11296_Jc_R_68vM5c.mp4
# rownum = 11296
# Labels = [3]
# Processing Line #10737
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11298_9hPRtAe--ys.mp4
# rownum = 11298
# Labels = [0]
# Processing Line #10738
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11299_GOhB95euLDE.mp4
# rownum = 11299
# Labels = [6]
# Processing Line #10739
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11300_MZoSJ6blBRk.mp4
# rownum = 11300
# Labels = [3]
# Processing Line #10740
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11302_gfxXRH-tV2U.mp4
# rownum = 11302
# Labels = [2, 1]
# Processing Line #10741
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11303_33ngUYmiGm0.mp4
# rownum = 11303
# Labels = [2]
# Processing Line #10742
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11304_PEqaMX5rTfQ.mp4
# rownum = 11304
# Labels = [6]
# Processing Line #10743
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11305_7BuvZEeXR6Y.mp4
# rownum = 11305
# Labels = [6]
# Processing Line #10744
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11306_DRWjQe_N83A.mp4
# rownum = 11306
# Labels = [0]
# Processing Line #10745
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11307_XiAYv1Q5CmI.mp4
# rownum = 11307
# Labels = [5]
# Processing Line #10746
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11308_Snpw6cfOJkQ.mp4
# rownum = 11308
# Labels = [6]
# Processing Line #10747
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11309_0sHasJJA9d0.mp4
# rownum = 11309
# Labels = [6]
# Processing Line #10748
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11310_P0PbCdM5Big.mp4
# rownum = 11310
# Labels = [5]
# Processing Line #10749
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11311_WWarhS30T_s.mp4
# rownum = 11311
# Labels = [5]
# Processing Line #10750
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11312_T5WkmmxiJlw.mp4
# rownum = 11312
# Labels = [6]
# Processing Line #10751
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11313_PynQ3GvF5J8.mp4
# rownum = 11313
# Labels = [6]
# Processing Line #10752
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11314_2AvWyMhYgkM.mp4
# rownum = 11314
# Labels = [6]
# Processing Line #10753
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11315_sMewmcIcI9w.mp4
# rownum = 11315
# Labels = [1]
# Processing Line #10754
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11316_DAU-2i8-vr4.mp4
# rownum = 11316
# Labels = [0]
# Processing Line #10755
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11317_N63FymJt6vw.mp4
# rownum = 11317
# Labels = [6]
# Processing Line #10756
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11319_HvQPPXhvJ_Y.mp4
# rownum = 11319
# Labels = [2]
# Processing Line #10757
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11320_8cRY7S7hnF0.mp4
# rownum = 11320
# Labels = [5]
# Processing Line #10758
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11321_A7E01_FMX9E.mp4
# rownum = 11321
# Labels = [6]
# Processing Line #10759
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11322_BkgRBZNV4Q0.mp4
# rownum = 11322
# Labels = [4]
# Processing Line #10760
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11323_6rJA_w3p4O4.mp4
# rownum = 11323
# Labels = [5]
# Processing Line #10761
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11324_9eFNC6jXrB0.mp4
# rownum = 11324
# Labels = [6]
# Processing Line #10762
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11325_6c0PVYIV2FE.mp4
# rownum = 11325
# Labels = [0]
# Processing Line #10763
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11326_BgXxjiy-ziw.mp4
# rownum = 11326
# Labels = [6]
# Processing Line #10764
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11327_4xqvecbHr_A.mp4
# rownum = 11327
# Labels = [0]
# Processing Line #10765
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11328_NhjHfJES1mQ.mp4
# rownum = 11328
# Labels = [3]
# Processing Line #10766
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11329_MgjgffhhpVs.mp4
# rownum = 11329
# Labels = [5]
# Processing Line #10767
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11330_OoBTNAlY0qc.mp4
# rownum = 11330
# Labels = [4, 0]
# Processing Line #10768
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11331_-TTibxLuqQo.mp4
# rownum = 11331
# Labels = [2]
# Processing Line #10769
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11332_CGJhxXww9RU.mp4
# rownum = 11332
# Labels = [4]
# Processing Line #10770
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11333_LuUk5HO-jIY.mp4
# rownum = 11333
# Labels = [0, 3]
# Processing Line #10771
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11334_1nTt_OOAVZA.mp4
# rownum = 11334
# Labels = [2]
# Processing Line #10772
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11335_GE7fETLlY-8.mp4
# rownum = 11335
# Labels = [3]
# Processing Line #10773
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11336_Nt6TR3sBEI8.mp4
# rownum = 11336
# Labels = [4]
# Processing Line #10774
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11337_50NJtOZ5qO4.mp4
# rownum = 11337
# Labels = [5]
# Processing Line #10775
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11338_0BqINyy1Hrc.mp4
# rownum = 11338
# Labels = [0]
# Processing Line #10776
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11339_NxkUlw2sqAM.mp4
# rownum = 11339
# Labels = [3]
# Processing Line #10777
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11340_2ERZO4pgRNo.mp4
# rownum = 11340
# Labels = [1]
# Processing Line #10778
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11341_YMpMJBRWXbQ.mp4
# rownum = 11341
# Labels = [5]
# Processing Line #10779
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11342_SvtuWDF2IoU.mp4
# rownum = 11342
# Labels = [3]
# Processing Line #10780
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11343_JqpBnYq1pnM.mp4
# rownum = 11343
# Labels = [6]
# Processing Line #10781
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11344_aSz_WgLNPJQ.mp4
# rownum = 11344
# Labels = [5]
# Processing Line #10782
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11345_5n8R-Htz0uE.mp4
# rownum = 11345
# Labels = [0]
# Processing Line #10783
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11346_ClljN0qfK9o.mp4
# rownum = 11346
# Labels = [2]
# Processing Line #10784
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11347_YKYBGCokY5g.mp4
# rownum = 11347
# Labels = [3]
# Processing Line #10785
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11348_PsXEPsvhSqU.mp4
# rownum = 11348
# Labels = [4]
# Processing Line #10786
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11349_D-9kojXug90.mp4
# rownum = 11349
# Labels = [0]
# Processing Line #10787
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11350_3ktjLsrZ9Q4.mp4
# rownum = 11350
# Labels = [3]
# Processing Line #10788
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11351_crdVSeiB9Tk.mp4
# rownum = 11351
# Labels = [5]
# Processing Line #10789
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11352_PRj01d9dq_o.mp4
# rownum = 11352
# Labels = [4]
# Processing Line #10790
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11353_hetJWGh6eqE.mp4
# rownum = 11353
# Labels = [5]
# Processing Line #10791
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11354_C6rohe-t1iU.mp4
# rownum = 11354
# Labels = [3]
# Processing Line #10792
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11355_K2EuMb92X7c.mp4
# rownum = 11355
# Labels = [2]
# Processing Line #10793
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11356_OuK9zeD4kig.mp4
# rownum = 11356
# Labels = [1]
# Processing Line #10794
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11357_YpceMhbnyQU.mp4
# rownum = 11357
# Labels = [5]
# Processing Line #10795
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11358_n2uGfWET7AU.mp4
# rownum = 11358
# Labels = [4]
# Processing Line #10796
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11359_9VMoLsCmCQE.mp4
# rownum = 11359
# Labels = [6]
# Processing Line #10797
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11360_W91FtuVK2_E.mp4
# rownum = 11360
# Labels = [4]
# Processing Line #10798
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11361_xB5ayMWljlk.mp4
# rownum = 11361
# Labels = [4]
# Processing Line #10799
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11362_ZjfAsfEV7Vs.mp4
# rownum = 11362
# Labels = [5]
# Processing Line #10800
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11363_XOfR-13OThM.mp4
# rownum = 11363
# Labels = [5]
# Processing Line #10801
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11365_50x_YCoSnIE.mp4
# rownum = 11365
# Labels = [0]
# Processing Line #10802
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11366_6Q5wl8EzONo.mp4
# rownum = 11366
# Labels = [2]
# Processing Line #10803
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11367_6N36Ym7cMm0.mp4
# rownum = 11367
# Labels = [0]
# Processing Line #10804
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11368_MGZgC343fWg.mp4
# rownum = 11368
# Labels = [0, 3]
# Processing Line #10805
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11369_NaDKgYadkfE.mp4
# rownum = 11369
# Labels = [2]
# Processing Line #10806
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11370_K4I4q3XRlXE.mp4
# rownum = 11370
# Labels = [3]
# Processing Line #10807
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11371_4X0YdEumX6k.mp4
# rownum = 11371
# Labels = [0]
# Processing Line #10808
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11372_0-4IBRA02K8.mp4
# rownum = 11372
# Labels = [0]
# Processing Line #10809
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11373_7M8CtoiLIhs.mp4
# rownum = 11373
# Labels = [6]
# Processing Line #10810
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11374_CKxlsWvaKOc.mp4
# rownum = 11374
# Labels = [6]
# Processing Line #10811
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11375_MjvCxGG_Pj8.mp4
# rownum = 11375
# Labels = [5]
# Processing Line #10812
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11376_Cv6mX-eGG3o.mp4
# rownum = 11376
# Labels = [2]
# Processing Line #10813
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11377_9IeMuY-MzlU.mp4
# rownum = 11377
# Labels = [0]
# Processing Line #10814
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11378_Zajazlk0Hu0.mp4
# rownum = 11378
# Labels = [0, 3]
# Processing Line #10815
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11379_nQy5YuL-W6A.mp4
# rownum = 11379
# Labels = [2, 1]
# Processing Line #10816
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11380__uhyaOAodWQ.mp4
# rownum = 11380
# Labels = [0, 3]
# Processing Line #10817
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11381_DawgOshVX38.mp4
# rownum = 11381
# Labels = [5]
# Processing Line #10818
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11382_UwVsZi5RRuc.mp4
# rownum = 11382
# Labels = [2]
# Processing Line #10819
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11383_SIRtKEm0rjM.mp4
# rownum = 11383
# Labels = [0, 3]
# Processing Line #10820
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11384_TbNKpHRSzVc.mp4
# rownum = 11384
# Labels = [2]
# Processing Line #10821
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11386_VKk4Ms_M6JQ.mp4
# rownum = 11386
# Labels = [6]
# Processing Line #10822
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11387_88ijmfzMRNo.mp4
# rownum = 11387
# Labels = [4]
# Processing Line #10823
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11388_-QFc1-0QD68.mp4
# rownum = 11388
# Labels = [2]
# Processing Line #10824
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11389_YmhiXQonJpk.mp4
# rownum = 11389
# Labels = [3]
# Processing Line #10825
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11390_CMNlIW6Lkwc.mp4
# rownum = 11390
# Labels = [5]
# Processing Line #10826
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11391_73FfGYOcAMk.mp4
# rownum = 11391
# Labels = [1]
# Processing Line #10827
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11392_K2PyWUNZdHE.mp4
# rownum = 11392
# Labels = [5]
# Processing Line #10828
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11393_74gZ_jBKbzY.mp4
# rownum = 11393
# Labels = [5]
# Processing Line #10829
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11394_CsjWzXhJ4Ow.mp4
# rownum = 11394
# Labels = [0]
# Processing Line #10830
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11395_6CrK4Gvr1bw.mp4
# rownum = 11395
# Labels = [0]
# Processing Line #10831
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11396_6vnRbHEfWHo.mp4
# rownum = 11396
# Labels = [0]
# Processing Line #10832
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11397_eVeMnxrVAKI.mp4
# rownum = 11397
# Labels = [5]
# Processing Line #10833
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11398_HaKqENh4cp0.mp4
# rownum = 11398
# Labels = [6]
# Processing Line #10834
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11399_8rwrbDUH6uM.mp4
# rownum = 11399
# Labels = [6]
# Processing Line #10835
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11400_mMtz47BMe70.mp4
# rownum = 11400
# Labels = [1]
# Processing Line #10836
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11401_H6pqewRQ_sg.mp4
# rownum = 11401
# Labels = [3]
# Processing Line #10837
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11402_PUJYW1Np_t4.mp4
# rownum = 11402
# Labels = [2]
# Processing Line #10838
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11403_ZatA1G8A_ec.mp4
# rownum = 11403
# Labels = [5, 4]
# Processing Line #10839
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11405_HqbTAtNuL6Y.mp4
# rownum = 11405
# Labels = [2]
# Processing Line #10840
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11406_rfM-Fpc8ofM.mp4
# rownum = 11406
# Labels = [1]
# Processing Line #10841
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11407_XyhP040uMcI.mp4
# rownum = 11407
# Labels = [5]
# Processing Line #10842
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11408_FmXRonhFnvo.mp4
# rownum = 11408
# Labels = [6]
# Processing Line #10843
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11409_OwkyPYIfmOg.mp4
# rownum = 11409
# Labels = [5]
# Processing Line #10844
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11410_U2KC9rij2Gs.mp4
# rownum = 11410
# Labels = [0, 3]
# Processing Line #10845
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11411_NVzxohzcni8.mp4
# rownum = 11411
# Labels = [5]
# Processing Line #10846
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11412_4uA1k8m0PmE.mp4
# rownum = 11412
# Labels = [5]
# Processing Line #10847
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11413_ChbA7ZYQ7g4.mp4
# rownum = 11413
# Labels = [2]
# Processing Line #10848
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11414_27Ia83p6rA4.mp4
# rownum = 11414
# Labels = [5]
# Processing Line #10849
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11415_SqHYPKuw-jw.mp4
# rownum = 11415
# Labels = [6]
# Processing Line #10850
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11416_Fl2WJbInWW4.mp4
# rownum = 11416
# Labels = [6]
# Processing Line #10851
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11417_I1sE_P3_OkU.mp4
# rownum = 11417
# Labels = [2]
# Processing Line #10852
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11418_8aYBID0muwQ.mp4
# rownum = 11418
# Labels = [5]
# Processing Line #10853
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11419_KE5tI-xYTmo.mp4
# rownum = 11419
# Labels = [4, 0]
# Processing Line #10854
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11420_19qNZuPUkcY.mp4
# rownum = 11420
# Labels = [0]
# Processing Line #10855
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11421_5rJULHMMt7Y.mp4
# rownum = 11421
# Labels = [4]
# Processing Line #10856
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11422_Flx4weDlM68.mp4
# rownum = 11422
# Labels = [4, 0]
# Processing Line #10857
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11423_4S3dEhCfy3Y.mp4
# rownum = 11423
# Labels = [5]
# Processing Line #10858
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11424_TMMP6bWMWto.mp4
# rownum = 11424
# Labels = [5]
# Processing Line #10859
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11425_LmXa1u0mm0A.mp4
# rownum = 11425
# Labels = [3]
# Processing Line #10860
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11426_KVwYxmRyUlY.mp4
# rownum = 11426
# Labels = [1]
# Processing Line #10861
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11427_4lNsWi99V5Y.mp4
# rownum = 11427
# Labels = [3]
# Processing Line #10862
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11428_7FJNYg1D4Bs.mp4
# rownum = 11428
# Labels = [0]
# Processing Line #10863
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11429_Ishmv9RnBSs.mp4
# rownum = 11429
# Labels = [6]
# Processing Line #10864
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11430_NklvcOBYvEo.mp4
# rownum = 11430
# Labels = [2]
# Processing Line #10865
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11431_2QX7_GceNp4.mp4
# rownum = 11431
# Labels = [6]
# Processing Line #10866
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11432_EbBnmvUFhEw.mp4
# rownum = 11432
# Labels = [2]
# Processing Line #10867
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11433_P0SWuMWq6LQ.mp4
# rownum = 11433
# Labels = [5]
# Processing Line #10868
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11434_HnK-atqtG3w.mp4
# rownum = 11434
# Labels = [6]
# Processing Line #10869
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11435_B8Fowlh71-M.mp4
# rownum = 11435
# Labels = [0]
# Processing Line #10870
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11436_3tUThedOHgs.mp4
# rownum = 11436
# Labels = [0]
# Processing Line #10871
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11437_UnTv_qUpfF0.mp4
# rownum = 11437
# Labels = [3]
# Processing Line #10872
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11438_WiVLZGN6jkU.mp4
# rownum = 11438
# Labels = [4, 0]
# Processing Line #10873
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11439_YlMdf5pQ-TM.mp4
# rownum = 11439
# Labels = [5]
# Processing Line #10874
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11440_9CxBeHs1dXY.mp4
# rownum = 11440
# Labels = [3]
# Processing Line #10875
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11441_BArGupQhId8.mp4
# rownum = 11441
# Labels = [0]
# Processing Line #10876
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11442_5UttiEguxs0.mp4
# rownum = 11442
# Labels = [6]
# Processing Line #10877
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11443_cuaPe4GHzfU.mp4
# rownum = 11443
# Labels = [4]
# Processing Line #10878
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11444_9tzaK38fOqc.mp4
# rownum = 11444
# Labels = [0]
# Processing Line #10879
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11445_1y18ync-kLA.mp4
# rownum = 11445
# Labels = [0]
# Processing Line #10880
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11446_-NCShvdIlTo.mp4
# rownum = 11446
# Labels = [6]
# Processing Line #10881
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11447_OGKkX7hf8gQ.mp4
# rownum = 11447
# Labels = [0, 3]
# Processing Line #10882
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11448_SX4eWEdAQ0Y.mp4
# rownum = 11448
# Labels = [6]
# Processing Line #10883
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11449_SSvx7pLqilw.mp4
# rownum = 11449
# Labels = [6]
# Processing Line #10884
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11450_U-b78Zc45GA.mp4
# rownum = 11450
# Labels = [6]
# Processing Line #10885
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11451_Ift6XjEAhTs.mp4
# rownum = 11451
# Labels = [2]
# Processing Line #10886
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11452_5zX3cmlLxwI.mp4
# rownum = 11452
# Labels = [0]
# Processing Line #10887
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11453_N3hU6tyyr0o.mp4
# rownum = 11453
# Labels = [5]
# Processing Line #10888
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11454_PLNguAAf7P0.mp4
# rownum = 11454
# Labels = [2]
# Processing Line #10889
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11455_FTPLIbmvoSs.mp4
# rownum = 11455
# Labels = [6]
# Processing Line #10890
# /home/rabreu/projeto_multimodal/data/2000unbalanced_train/video/11456_0qERZHsSX6I.mp4
# rownum = 11456
# Labels = [5]
# Processing Line #10891
# ...
# rownum = 431
# Labels = [4, 0]
# Processing Line #396
# /home/rabreu/projeto_multimodal/data/eval/video/432_hHFqyvBK8cE.mp4
# rownum = 432
# Labels = [4]
# Processing Line #397
# /home/rabreu/projeto_multimodal/data/eval/video/433_hIYihNrwF2Q.mp4
# rownum = 433
# Labels = [6]
# Processing Line #398
# /home/rabreu/projeto_multimodal/data/eval/video/434_hQYTMFCLy5E.mp4
# rownum = 434
# Labels = [4, 0]
# Processing Line #399
# /home/rabreu/projeto_multimodal/data/eval/video/435_hR3hr7g-bDs.mp4
# rownum = 435
# Labels = [5]
# Processing Line #400
# /home/rabreu/projeto_multimodal/data/eval/video/436_h__4MI_GgpM.mp4
# rownum = 436
# Labels = [6]
# Processing Line #401
# /home/rabreu/projeto_multimodal/data/eval/video/437_hl19xAqJqoQ.mp4
# rownum = 437
# Labels = [0]
# Processing Line #402
# /home/rabreu/projeto_multimodal/data/eval/video/438_hl9AzFQ4Hus.mp4
# rownum = 438
# Labels = [0, 3]
# Processing Line #403
# /home/rabreu/projeto_multimodal/data/eval/video/439_hmD1w6133Og.mp4
# rownum = 439
# Labels = [6]
# Processing Line #404
# /home/rabreu/projeto_multimodal/data/eval/video/440_hzQyTOaBHzI.mp4
# rownum = 440
# Labels = [2]
# Processing Line #405
# /home/rabreu/projeto_multimodal/data/eval/video/441_iE4ructiJNo.mp4
# rownum = 441
# Labels = [6]
# Processing Line #406
# /home/rabreu/projeto_multimodal/data/eval/video/442_iMNEd2l5Ff8.mp4
# rownum = 442
# Labels = [6]
# Processing Line #407
# /home/rabreu/projeto_multimodal/data/eval/video/443_iRKgAwNtM24.mp4
# rownum = 443
# Labels = [4]
# Processing Line #408
# /home/rabreu/projeto_multimodal/data/eval/video/444_iZxPrZAZeXY.mp4
# rownum = 444
# Labels = [0]
# Processing Line #409
# /home/rabreu/projeto_multimodal/data/eval/video/445_icKojlQtWv0.mp4
# rownum = 445
# Labels = [3]
# Processing Line #410
# /home/rabreu/projeto_multimodal/data/eval/video/446_igTZmll9MN8.mp4
# rownum = 446
# Labels = [6]
# Processing Line #411
# /home/rabreu/projeto_multimodal/data/eval/video/447_iw8AL6xHoYE.mp4
# rownum = 447
# Labels = [0]
# Processing Line #412
# /home/rabreu/projeto_multimodal/data/eval/video/448_jAXka8pSqRw.mp4
# rownum = 448
# Labels = [2]
# Processing Line #413
# /home/rabreu/projeto_multimodal/data/eval/video/449_jGrIgDaqDR8.mp4
# rownum = 449
# Labels = [0]
# Processing Line #414
# /home/rabreu/projeto_multimodal/data/eval/video/450_jJrP7ZF9_WA.mp4
# rownum = 450
# Labels = [4]
# Processing Line #415
# /home/rabreu/projeto_multimodal/data/eval/video/451_jU0LDjmqrRw.mp4
# rownum = 451
# Labels = [0, 3]
# Processing Line #416
# /home/rabreu/projeto_multimodal/data/eval/video/452_jlgz0tRGQYM.mp4
# rownum = 452
# Labels = [6]
# Processing Line #417
# /home/rabreu/projeto_multimodal/data/eval/video/453_jnrA1sig4t8.mp4
# rownum = 453
# Labels = [0, 3]
# Processing Line #418
# /home/rabreu/projeto_multimodal/data/eval/video/454_johz0yXuORc.mp4
# rownum = 454
# Labels = [2]
# Processing Line #419
# /home/rabreu/projeto_multimodal/data/eval/video/456_kTyq_6AnoSw.mp4
# rownum = 456
# Labels = [6]
# Processing Line #420
# /home/rabreu/projeto_multimodal/data/eval/video/457_kb3tfk8dxvU.mp4
# rownum = 457
# Labels = [6]
# Processing Line #421
# /home/rabreu/projeto_multimodal/data/eval/video/458_kdO5ekG8Mp8.mp4
# rownum = 458
# Labels = [4, 0]
# Processing Line #422
# /home/rabreu/projeto_multimodal/data/eval/video/459_kf0YrFpuNKQ.mp4
# rownum = 459
# Labels = [6]
# Processing Line #423
# /home/rabreu/projeto_multimodal/data/eval/video/460_khvH4CSuKyg.mp4
# rownum = 460
# Labels = [0]
# Processing Line #424
# /home/rabreu/projeto_multimodal/data/eval/video/461_krwEhbbxSw4.mp4
# rownum = 461
# Labels = [0]
# Processing Line #425
# /home/rabreu/projeto_multimodal/data/eval/video/462_kzxanav4Q34.mp4
# rownum = 462
# Labels = [3]
# Processing Line #426
# /home/rabreu/projeto_multimodal/data/eval/video/463_l1BhWvXU4bY.mp4
# rownum = 463
# Labels = [2]
# Processing Line #427
# /home/rabreu/projeto_multimodal/data/eval/video/464_l4SwCMe4Kl4.mp4
# rownum = 464
# Labels = [5]
# Processing Line #428
# /home/rabreu/projeto_multimodal/data/eval/video/465_l5zOsyE1LBE.mp4
# rownum = 465
# Labels = [0, 3]
# Processing Line #429
# /home/rabreu/projeto_multimodal/data/eval/video/466_l6HsxUNdkd4.mp4
# rownum = 466
# Labels = [6]
# Processing Line #430
# /home/rabreu/projeto_multimodal/data/eval/video/467_lJTpC9bjne0.mp4
# rownum = 467
# Labels = [0]
# Processing Line #431
# /home/rabreu/projeto_multimodal/data/eval/video/468_lKOgVeuSmts.mp4
# rownum = 468
# Labels = [0]
# Processing Line #432
# /home/rabreu/projeto_multimodal/data/eval/video/469_lN5WWx9YD3k.mp4
# rownum = 469
# Labels = [2]
# Processing Line #433
# /home/rabreu/projeto_multimodal/data/eval/video/470_lS3jp74mLHk.mp4
# rownum = 470
# Labels = [4, 0]
# Processing Line #434
# /home/rabreu/projeto_multimodal/data/eval/video/471_lSr8MKcWTdo.mp4
# rownum = 471
# Labels = [6]
# Processing Line #435
# /home/rabreu/projeto_multimodal/data/eval/video/472_ldVtte9jK-s.mp4
# rownum = 472
# Labels = [6]
# Processing Line #436
# /home/rabreu/projeto_multimodal/data/eval/video/474_m-XV3AbXE3o.mp4
# rownum = 474
# Labels = [2, 1]
# Processing Line #437
# /home/rabreu/projeto_multimodal/data/eval/video/475_mA9Rin6YF5w.mp4
# rownum = 475
# Labels = [5]
# Processing Line #438
# /home/rabreu/projeto_multimodal/data/eval/video/476_mC7nCm_mnwA.mp4
# rownum = 476
# Labels = [6]
# Processing Line #439
# /home/rabreu/projeto_multimodal/data/eval/video/477_mHiOGhxbmdo.mp4
# rownum = 477
# Labels = [6]
# Processing Line #440
# /home/rabreu/projeto_multimodal/data/eval/video/478_mOHPhSz4vMA.mp4
# rownum = 478
# Labels = [2]
# Processing Line #441
# /home/rabreu/projeto_multimodal/data/eval/video/479_mTM0WQRcfNU.mp4
# rownum = 479
# Labels = [6]
# Processing Line #442
# /home/rabreu/projeto_multimodal/data/eval/video/480_maxlwbbBWU8.mp4
# rownum = 480
# Labels = [2, 1]
# Processing Line #443
# /home/rabreu/projeto_multimodal/data/eval/video/481_meYai_zs_3k.mp4
# rownum = 481
# Labels = [2]
# Processing Line #444
# /home/rabreu/projeto_multimodal/data/eval/video/482_mfPRLpelDuQ.mp4
# rownum = 482
# Labels = [2, 1]
# Processing Line #445
# /home/rabreu/projeto_multimodal/data/eval/video/483_ml07DEX7png.mp4
# rownum = 483
# Labels = [6]
# Processing Line #446
# /home/rabreu/projeto_multimodal/data/eval/video/485_mwZ__VNBuJU.mp4
# rownum = 485
# Labels = [6]
# Processing Line #447
# /home/rabreu/projeto_multimodal/data/eval/video/486_myy-OtJbCfQ.mp4
# rownum = 486
# Labels = [0, 3]
# Processing Line #448
# /home/rabreu/projeto_multimodal/data/eval/video/487_n-A3BJEpmz8.mp4
# rownum = 487
# Labels = [0]
# Processing Line #449
# /home/rabreu/projeto_multimodal/data/eval/video/488_n85R3OXK3bs.mp4
# rownum = 488
# Labels = [4, 0]
# Processing Line #450
# /home/rabreu/projeto_multimodal/data/eval/video/489_nGTYKpIhyag.mp4
# rownum = 489
# Labels = [2]
# Processing Line #451
# /home/rabreu/projeto_multimodal/data/eval/video/490_nLaw4KMlTn0.mp4
# rownum = 490
# Labels = [2]
# Processing Line #452
# /home/rabreu/projeto_multimodal/data/eval/video/491_nWlDkrIzc0g.mp4
# rownum = 491
# Labels = [6]
# Processing Line #453
# /home/rabreu/projeto_multimodal/data/eval/video/492_nbuyVi6v7SY.mp4
# rownum = 492
# Labels = [6]
# Processing Line #454
# /home/rabreu/projeto_multimodal/data/eval/video/493_o2oGJ1jhzNM.mp4
# rownum = 493
# Labels = [2]
# Processing Line #455
# /home/rabreu/projeto_multimodal/data/eval/video/494_o3qLyDuP37w.mp4
# rownum = 494
# Labels = [2, 1]
# Processing Line #456
# /home/rabreu/projeto_multimodal/data/eval/video/495_o9PB_HGeUzs.mp4
# rownum = 495
# Labels = [5]
# Processing Line #457
# /home/rabreu/projeto_multimodal/data/eval/video/496_oQx75zhujZE.mp4
# rownum = 496
# Labels = [2]
# Processing Line #458
# /home/rabreu/projeto_multimodal/data/eval/video/497_oRLzsvwP-0I.mp4
# rownum = 497
# Labels = [4, 0]
# Processing Line #459
# /home/rabreu/projeto_multimodal/data/eval/video/498_ovgelLpt148.mp4
# rownum = 498
# Labels = [6]
# Processing Line #460
# /home/rabreu/projeto_multimodal/data/eval/video/499_p1gQTumLv5M.mp4
# rownum = 499
# Labels = [6]
# Processing Line #461
# /home/rabreu/projeto_multimodal/data/eval/video/500_pEDafzZbNwE.mp4
# rownum = 500
# Labels = [6]
# Processing Line #462
# /home/rabreu/projeto_multimodal/data/eval/video/501_pTRiK6Cc9fo.mp4
# rownum = 501
# Labels = [0]
# Processing Line #463
# /home/rabreu/projeto_multimodal/data/eval/video/502_pizFsY0yjss.mp4
# rownum = 502
# Labels = [5]
# Processing Line #464
# /home/rabreu/projeto_multimodal/data/eval/video/503_przrSPZgOkY.mp4
# rownum = 503
# Labels = [2, 1]
# Processing Line #465
# /home/rabreu/projeto_multimodal/data/eval/video/504_q3YnX6-OmYQ.mp4
# rownum = 504
# Labels = [6]
# Processing Line #466
# /home/rabreu/projeto_multimodal/data/eval/video/505_q3qm4bSfpu8.mp4
# rownum = 505
# Labels = [0]
# Processing Line #467
# /home/rabreu/projeto_multimodal/data/eval/video/506_q9YBqlAwDec.mp4
# rownum = 506
# Labels = [2]
# Processing Line #468
# /home/rabreu/projeto_multimodal/data/eval/video/507_qEAXFUmJB9s.mp4
# rownum = 507
# Labels = [0, 3]
# Processing Line #469
# /home/rabreu/projeto_multimodal/data/eval/video/509_qqHU2B2RZvQ.mp4
# rownum = 509
# Labels = [0, 3]
# Processing Line #470
# /home/rabreu/projeto_multimodal/data/eval/video/510_qvfnNyzjFOA.mp4
# rownum = 510
# Labels = [3]
# Processing Line #471
# /home/rabreu/projeto_multimodal/data/eval/video/511_qw1vm_wdpy0.mp4
# rownum = 511
# Labels = [5]
# Processing Line #472
# /home/rabreu/projeto_multimodal/data/eval/video/512_r2jHs1Nbrqw.mp4
# rownum = 512
# Labels = [2, 1]
# Processing Line #473
# /home/rabreu/projeto_multimodal/data/eval/video/513_rDb0xQ6m8Oc.mp4
# rownum = 513
# Labels = [0]
# Processing Line #474
# /home/rabreu/projeto_multimodal/data/eval/video/514_rYojIIvr1w8.mp4
# rownum = 514
# Labels = [6]
# Processing Line #475
# /home/rabreu/projeto_multimodal/data/eval/video/515_rhMpRPQlwmY.mp4
# rownum = 515
# Labels = [6]
# Processing Line #476
# /home/rabreu/projeto_multimodal/data/eval/video/516_rkWJNG4N-U4.mp4
# rownum = 516
# Labels = [4]
# Processing Line #477
# /home/rabreu/projeto_multimodal/data/eval/video/517_rnSSF1DaXww.mp4
# rownum = 517
# Labels = [6]
# Processing Line #478
# /home/rabreu/projeto_multimodal/data/eval/video/518_rysr8w7aTuQ.mp4
# rownum = 518
# Labels = [6]
# Processing Line #479
# /home/rabreu/projeto_multimodal/data/eval/video/519_s-xeIHv59yY.mp4
# rownum = 519
# Labels = [6]
# Processing Line #480
# /home/rabreu/projeto_multimodal/data/eval/video/520_s0zVS4ZWcZc.mp4
# rownum = 520
# Labels = [3]
# Processing Line #481
# /home/rabreu/projeto_multimodal/data/eval/video/521_sFXjJww9mCU.mp4
# rownum = 521
# Labels = [2]
# Processing Line #482
# /home/rabreu/projeto_multimodal/data/eval/video/522_sZ9O8hhwsRY.mp4
# rownum = 522
# Labels = [0, 3]
# Processing Line #483
# /home/rabreu/projeto_multimodal/data/eval/video/523_skxOyyYReQk.mp4
# rownum = 523
# Labels = [0]
# Processing Line #484
# /home/rabreu/projeto_multimodal/data/eval/video/524_sngiPk6sTBs.mp4
# rownum = 524
# Labels = [4]
# Processing Line #485
# /home/rabreu/projeto_multimodal/data/eval/video/525_t7AV9-bdUA8.mp4
# rownum = 525
# Labels = [3]
# Processing Line #486
# /home/rabreu/projeto_multimodal/data/eval/video/527_t9PEpPvVNzI.mp4
# rownum = 527
# Labels = [6]
# Processing Line #487
# /home/rabreu/projeto_multimodal/data/eval/video/528_tJ9xvSEstWE.mp4
# rownum = 528
# Labels = [4, 0]
# Processing Line #488
# /home/rabreu/projeto_multimodal/data/eval/video/529_tWJxVNq0N5E.mp4
# rownum = 529
# Labels = [0]
# Processing Line #489
# /home/rabreu/projeto_multimodal/data/eval/video/530_thCn14bf1r8.mp4
# rownum = 530
# Labels = [6]
# Processing Line #490
# /home/rabreu/projeto_multimodal/data/eval/video/531_toXKyZwVNpI.mp4
# rownum = 531
# Labels = [4]
# Processing Line #491
# /home/rabreu/projeto_multimodal/data/eval/video/532_tuvoP6QvMQ4.mp4
# rownum = 532
# Labels = [6]
# Processing Line #492
# /home/rabreu/projeto_multimodal/data/eval/video/533_u5sX_EosnV8.mp4
# rownum = 533
# Labels = [4]
# Processing Line #493
# /home/rabreu/projeto_multimodal/data/eval/video/534_u82ptblJvog.mp4
# rownum = 534
# Labels = [5]
# Processing Line #494
# /home/rabreu/projeto_multimodal/data/eval/video/535_uRyLEBGX5ag.mp4
# rownum = 535
# Labels = [6]
# Processing Line #495
# /home/rabreu/projeto_multimodal/data/eval/video/536_uWEp_4fHX4Y.mp4
# rownum = 536
# Labels = [4, 0]
# Processing Line #496
# /home/rabreu/projeto_multimodal/data/eval/video/537_uWjhTmqkIdU.mp4
# rownum = 537
# Labels = [4, 0]
# Processing Line #497
# /home/rabreu/projeto_multimodal/data/eval/video/538_uXVa0VyKdm0.mp4
# rownum = 538
# Labels = [6]
# Processing Line #498
# /home/rabreu/projeto_multimodal/data/eval/video/539_u_Nxu8TvonA.mp4
# rownum = 539
# Labels = [6]
# Processing Line #499
# /home/rabreu/projeto_multimodal/data/eval/video/540_ugK4AsMEVsg.mp4
# rownum = 540
# Labels = [2]
# Processing Line #500
# /home/rabreu/projeto_multimodal/data/eval/video/541_unOXaB3QoYk.mp4
# rownum = 541
# Labels = [6]
# Processing Line #501
# /home/rabreu/projeto_multimodal/data/eval/video/542_urZASbmHOO8.mp4
# rownum = 542
# Labels = [6]
# Processing Line #502
# /home/rabreu/projeto_multimodal/data/eval/video/543_uxy0ovI6cNU.mp4
# rownum = 543
# Labels = [0]
# Processing Line #503
# /home/rabreu/projeto_multimodal/data/eval/video/544_v5fePy2J1XU.mp4
# rownum = 544
# Labels = [0, 3]
# Processing Line #504
# /home/rabreu/projeto_multimodal/data/eval/video/545_v94qdpJqK9w.mp4
# rownum = 545
# Labels = [6]
# Processing Line #505
# /home/rabreu/projeto_multimodal/data/eval/video/546_vb1SalyslCs.mp4
# rownum = 546
# Labels = [0]
# Processing Line #506
# /home/rabreu/projeto_multimodal/data/eval/video/547_vhJeDYQVtdQ.mp4
# rownum = 547
# Labels = [4, 0]
# Processing Line #507
# /home/rabreu/projeto_multimodal/data/eval/video/548_vn_LymlQAnc.mp4
# rownum = 548
# Labels = [6]
# Processing Line #508
# /home/rabreu/projeto_multimodal/data/eval/video/550_wVMkSyxQ6IM.mp4
# rownum = 550
# Labels = [0]
# Processing Line #509
# /home/rabreu/projeto_multimodal/data/eval/video/551_wgg6YgGx4Rk.mp4
# rownum = 551
# Labels = [6]
# Processing Line #510
# /home/rabreu/projeto_multimodal/data/eval/video/552_wrLwSUzx0ek.mp4
# rownum = 552
# Labels = [4]
# Processing Line #511
# /home/rabreu/projeto_multimodal/data/eval/video/553_wuz0curb_hg.mp4
# rownum = 553
# Labels = [6]
# Processing Line #512
# /home/rabreu/projeto_multimodal/data/eval/video/554_wzjeayE_MWo.mp4
# rownum = 554
# Labels = [6]
# Processing Line #513
# /home/rabreu/projeto_multimodal/data/eval/video/555_x7RLEgi_tGU.mp4
# rownum = 555
# Labels = [6]
# Processing Line #514
# /home/rabreu/projeto_multimodal/data/eval/video/556_xFdFAEY7eTc.mp4
# rownum = 556
# Labels = [5]
# Processing Line #515
# /home/rabreu/projeto_multimodal/data/eval/video/557_xLgjhRyyYcI.mp4
# rownum = 557
# Labels = [2]
# Processing Line #516
# /home/rabreu/projeto_multimodal/data/eval/video/558_xWpmJvOkAyY.mp4
# rownum = 558
# Labels = [0]
# Processing Line #517
# /home/rabreu/projeto_multimodal/data/eval/video/559_xix27wqyXl8.mp4
# rownum = 559
# Labels = [2]
# Processing Line #518
# /home/rabreu/projeto_multimodal/data/eval/video/561_xs2gIcLi8DA.mp4
# rownum = 561
# Labels = [6]
# Processing Line #519
# /home/rabreu/projeto_multimodal/data/eval/video/563_yAR8i2eSHiE.mp4
# rownum = 563
# Labels = [0, 3]
# Processing Line #520
# /home/rabreu/projeto_multimodal/data/eval/video/564_yCp6DZqrdSs.mp4
# rownum = 564
# Labels = [0]
# Processing Line #521
# /home/rabreu/projeto_multimodal/data/eval/video/565_yOq3d33TSic.mp4
# rownum = 565
# Labels = [4, 0]
# Processing Line #522
# /home/rabreu/projeto_multimodal/data/eval/video/566_yszKc4m-W9U.mp4
# rownum = 566
# Labels = [6]
# Processing Line #523
# /home/rabreu/projeto_multimodal/data/eval/video/567_yu0De8n7Tog.mp4
# rownum = 567
# Labels = [0]
# Processing Line #524
# /home/rabreu/projeto_multimodal/data/eval/video/568_zMieepXr1Y4.mp4
# rownum = 568
# Labels = [6]
# Processing Line #525
# /home/rabreu/projeto_multimodal/data/eval/video/569_zQPKy8HMbDc.mp4
# rownum = 569
# Labels = [6]
# Processing Line #526
# /home/rabreu/projeto_multimodal/data/eval/video/570_zW_741B6ugQ.mp4
# rownum = 570
# Labels = [6]
# Processing Line #527
# /home/rabreu/projeto_multimodal/data/eval/video/571_zexkXRiD9zk.mp4
# rownum = 571
# Labels = [0]
# Processing Line #528
# /home/rabreu/projeto_multimodal/data/eval/video/572_ztfXxgXqHGM.mp4
# rownum = 572
# Labels = [6]
# Processing Line #529
# /home/rabreu/projeto_multimodal/data/eval/video/573_ztrU90Ub4Uw.mp4
# rownum = 573
# Labels = [5]
# Processing Line #530
# /home/rabreu/projeto_multimodal/data/eval/video/574_zwi96DG85AI.mp4
# rownum = 574
# Labels = [2]
# Processing Line #531
# /home/rabreu/projeto_multimodal/data/eval/video/575_zzbTaK7CXJY.mp4
# rownum = 575
# Labels = [0]
# Features of =  (532, 32, 32, 32, 3)
# Labels of =  (532, 7)
# Saved /home/rabreu/projeto_multimodal/data/eval/video/features/_x.npy
# Saved /home/rabreu/projeto_multimodal/data/eval/video/features/_y.npy

# %% [markdown]
# ### Carregando dados

# %%
# Load up numpy arrays to save time if they have already been procesed.

save_dir = data_dir+train_sub_dir+"/2000features/"
feature_file = os.path.join(save_dir+'_x.npy')
labels_file = os.path.join(save_dir+'_y.npy')
train_x = np.load(feature_file)
train_y = np.load(labels_file)
print(train_x.shape)


save_dir = data_dir+eval_sub_dir+"/features/"
feature_file = os.path.join(save_dir+'_x.npy')
labels_file = os.path.join(save_dir+'_y.npy')
eval_x = np.load(feature_file)
eval_y = np.load(labels_file)
print(eval_x.shape)
# Out:
# (10950, 32, 32, 32, 3)
# (532, 32, 32, 32, 3)

# %%
fps_trimmed = 3 # get four frames each second
max_frames = 32 # cut the video past this treshold
frame_size = 32 # 32x32 pixels

# %%
n_dim = np.empty((max_frames,frame_size,frame_size,3)).shape  # TODO: Fazer o slicing do train_x corretamente. 
n_classes = train_y.shape[1]

print "Feature Dimension:", n_dim, "Classes:", n_classes
# Out:
# Feature Dimension: (32, 32, 32, 3) Classes: 7

# %%
## Mapeando valores para o espaço entre 0 e 1... será que dá diferença?

train_x = train_x.astype('float32')
eval_x = eval_x.astype('float32')
train_x  /= 255
eval_x /= 255

# %% [markdown]
# ### Time distributed

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.layers import Lambda
from keras.layers import Input
from keras.models import Model


from keras.layers.merge import concatenate


from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.wrappers import TimeDistributed
from keras.layers.recurrent import LSTM

from keras.optimizers import SGD


import keras.backend as K

print(n_dim)
# o modelo original não tinha padding no maxpooling. 
#Tive que inserir para comportar nosso tamanho de imagem que é de 32x32 atualmente

video_input  = Input(shape=(n_dim),name='video_input')

#model.add(BatchNormalization(epsilon=1e-06,input_shape=n_dim, axis = 1, momentum=0.9, weights=None)) # Normalizar no input vale a pena? talvez seja algo a testar.


video = TimeDistributed(Conv2D(32, (3, 3), strides=(2, 2),
    activation='relu', padding='same',data_format="channels_last"), input_shape=n_dim)(video_input)
video = TimeDistributed(BatchNormalization())(video)
video = TimeDistributed(Conv2D(32, (3,3),
    padding='same', activation='relu'))(video)
video = TimeDistributed(BatchNormalization())(video)
video = TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2)))(video)

video = TimeDistributed(Dropout(0.5))(video)



video = TimeDistributed(Conv2D(64, (3,3),
    padding='same', activation='relu'))(video)
video = TimeDistributed(BatchNormalization())(video)
video = TimeDistributed(Conv2D(64, (3,3),
    padding='same', activation='relu'))(video)
video = TimeDistributed(BatchNormalization())(video)
video = TimeDistributed(MaxPooling2D((2, 2),padding="same", strides=(2, 2)))(video)
#model.add(Dropout(0.5))



video = TimeDistributed(Conv2D(128, (3,3),
    padding='same', activation='relu',kernel_initializer='uniform'))(video)
video = TimeDistributed(BatchNormalization())(video)
video = TimeDistributed(Conv2D(128, (3,3),
    padding='same', activation='relu'))(video)
video = TimeDistributed(BatchNormalization())(video)
video = TimeDistributed(MaxPooling2D((2, 2),padding="same", strides=(2, 2)))(video)


#model.add(TimeDistributed(Conv2D(256, (3,3),
#    padding='same', activation='relu')))
#model.add(TimeDistributed(Conv2D(256, (3,3),
#    padding='same', activation='relu')))
#model.add(TimeDistributed(MaxPooling2D((2, 2),padding="same", strides=(2, 2),data_format="channels_last")))

#model.add(TimeDistributed(BatchNormalization()))

#model.add(TimeDistributed(Conv2D(512, (3,3),
#    padding='same', activation='relu')))
#model.add(TimeDistributed(Conv2D(512, (3,3),
#    padding='same', activation='relu')))
#model.add(TimeDistributed(MaxPooling2D((2, 2),padding="same", strides=(2, 2))))

video = TimeDistributed(Flatten())(video)
#video = Flatten()(video) seráaa??

#model.add(Dropout(0.5))
video =  LSTM(256, return_sequences=False)(video)
video =  Dropout(0.5)(video)
video =  Dense(1000, activation='relu')(video)
video =  Dropout(0.5)(video)

main_output = Dense(n_classes, activation='sigmoid',name='main_output')(video)
model = Model(inputs=[video_input], outputs=main_output)

sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['binary_accuracy'])
# Out:
# (32, 32, 32, 3)

# %%
# Out:
# (None, 32, 512)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# video_input (InputLayer)     (None, 32, 32, 32, 3)     0
# _________________________________________________________________
# time_distributed_79 (TimeDis (None, 32, 16, 16, 32)    896
# _________________________________________________________________
# time_distributed_80 (TimeDis (None, 32, 16, 16, 32)    128
# _________________________________________________________________
# time_distributed_81 (TimeDis (None, 32, 16, 16, 32)    9248
# _________________________________________________________________
# time_distributed_82 (TimeDis (None, 32, 16, 16, 32)    128
# _________________________________________________________________
# time_distributed_83 (TimeDis (None, 32, 8, 8, 32)      0
# _________________________________________________________________
# time_distributed_84 (TimeDis (None, 32, 8, 8, 32)      0
# _________________________________________________________________
# time_distributed_85 (TimeDis (None, 32, 8, 8, 64)      18496
# _________________________________________________________________
# time_distributed_86 (TimeDis (None, 32, 8, 8, 64)      256
# _________________________________________________________________
# time_distributed_87 (TimeDis (None, 32, 8, 8, 64)      36928
# _________________________________________________________________
# time_distributed_88 (TimeDis (None, 32, 8, 8, 64)      256
# _________________________________________________________________
# time_distributed_89 (TimeDis (None, 32, 4, 4, 64)      0
# _________________________________________________________________
# time_distributed_90 (TimeDis (None, 32, 4, 4, 128)     73856
# _________________________________________________________________
# time_distributed_91 (TimeDis (None, 32, 4, 4, 128)     512
# _________________________________________________________________
# time_distributed_92 (TimeDis (None, 32, 4, 4, 128)     147584
# _________________________________________________________________
# time_distributed_93 (TimeDis (None, 32, 4, 4, 128)     512
# _________________________________________________________________
# time_distributed_94 (TimeDis (None, 32, 2, 2, 128)     0
# _________________________________________________________________
# time_distributed_95 (TimeDis (None, 32, 512)           0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 256)               787456
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1000)              257000
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# main_output (Dense)          (None, 7)                 7007
# =================================================================
# Total params: 1,340,263
# Trainable params: 1,339,367
# Non-trainable params: 896
# _________________________________________________________________

# %%
metrics = custom_metrics()
hist = model.fit(x = train_x,
                 y = train_y,
                 validation_data=(eval_x,eval_y),
                 batch_size=32,
                 epochs = 40,
                 callbacks=[metrics])
# Out:
# Train on 10950 samples, validate on 532 samples
# Epoch 1/40
# 10950/10950 [==============================] - 32s 3ms/step - loss: 0.4295 - binary_accuracy: 0.8276 - val_loss: 0.5076 - val_binary_accuracy: 0.8126
# Epoch 2/40
#    64/10950 [..............................] - ETA: 30s - loss: 0.4118 - binary_accuracy: 0.8147
# /home/rabreu/projeto_multimodal/venv/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rabreu/projeto_multimodal/venv/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.4048 - binary_accuracy: 0.8328 - val_loss: 0.4280 - val_binary_accuracy: 0.8166
# Epoch 3/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3950 - binary_accuracy: 0.8355 - val_loss: 0.4045 - val_binary_accuracy: 0.8244
# Epoch 4/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3844 - binary_accuracy: 0.8389 - val_loss: 0.3936 - val_binary_accuracy: 0.8244
# Epoch 5/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3816 - binary_accuracy: 0.8403 - val_loss: 0.4008 - val_binary_accuracy: 0.8316
# Epoch 6/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3756 - binary_accuracy: 0.8422 - val_loss: 0.3892 - val_binary_accuracy: 0.8386
# Epoch 7/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3712 - binary_accuracy: 0.8427 - val_loss: 0.3993 - val_binary_accuracy: 0.8316
# Epoch 8/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3625 - binary_accuracy: 0.8470 - val_loss: 0.4301 - val_binary_accuracy: 0.8179
# Epoch 9/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3601 - binary_accuracy: 0.8483 - val_loss: 0.4055 - val_binary_accuracy: 0.8147
# Epoch 10/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3547 - binary_accuracy: 0.8502 - val_loss: 0.4191 - val_binary_accuracy: 0.8220
# Epoch 11/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3512 - binary_accuracy: 0.8518 - val_loss: 0.3899 - val_binary_accuracy: 0.8271
# Epoch 12/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3486 - binary_accuracy: 0.8520 - val_loss: 0.3933 - val_binary_accuracy: 0.8289
# Epoch 13/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3450 - binary_accuracy: 0.8535 - val_loss: 0.4243 - val_binary_accuracy: 0.8064
# Epoch 14/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3405 - binary_accuracy: 0.8569 - val_loss: 0.3947 - val_binary_accuracy: 0.8268
# Epoch 15/40
# 10950/10950 [==============================] - 29s 3ms/step - loss: 0.3358 - binary_accuracy: 0.8578 - val_loss: 0.3709 - val_binary_accuracy: 0.8386
# Epoch 16/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3329 - binary_accuracy: 0.8588 - val_loss: 0.4372 - val_binary_accuracy: 0.8161
# Epoch 17/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3292 - binary_accuracy: 0.8596 - val_loss: 0.3877 - val_binary_accuracy: 0.8289
# Epoch 18/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3265 - binary_accuracy: 0.8604 - val_loss: 0.3780 - val_binary_accuracy: 0.8357
# Epoch 19/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3238 - binary_accuracy: 0.8626 - val_loss: 0.3953 - val_binary_accuracy: 0.8244
# Epoch 20/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3188 - binary_accuracy: 0.8653 - val_loss: 0.4082 - val_binary_accuracy: 0.8206
# Epoch 21/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3176 - binary_accuracy: 0.8645 - val_loss: 0.3674 - val_binary_accuracy: 0.8400
# Epoch 22/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3116 - binary_accuracy: 0.8674 - val_loss: 0.4366 - val_binary_accuracy: 0.8099
# Epoch 23/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3087 - binary_accuracy: 0.8686 - val_loss: 0.3864 - val_binary_accuracy: 0.8271
# Epoch 24/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3056 - binary_accuracy: 0.8700 - val_loss: 0.3503 - val_binary_accuracy: 0.8531
# Epoch 25/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.3014 - binary_accuracy: 0.8734 - val_loss: 0.3859 - val_binary_accuracy: 0.8335
# Epoch 26/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2993 - binary_accuracy: 0.8724 - val_loss: 0.3926 - val_binary_accuracy: 0.8298
# Epoch 27/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2927 - binary_accuracy: 0.8765 - val_loss: 0.3755 - val_binary_accuracy: 0.8327
# Epoch 28/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2906 - binary_accuracy: 0.8777 - val_loss: 0.3988 - val_binary_accuracy: 0.8289
# Epoch 29/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2891 - binary_accuracy: 0.8762 - val_loss: 0.3670 - val_binary_accuracy: 0.8330
# Epoch 30/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2818 - binary_accuracy: 0.8810 - val_loss: 0.3948 - val_binary_accuracy: 0.8220
# Epoch 31/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2818 - binary_accuracy: 0.8813 - val_loss: 0.3735 - val_binary_accuracy: 0.8359
# Epoch 32/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2765 - binary_accuracy: 0.8819 - val_loss: 0.3853 - val_binary_accuracy: 0.8346
# Epoch 33/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2704 - binary_accuracy: 0.8865 - val_loss: 0.4028 - val_binary_accuracy: 0.8238
# Epoch 34/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2680 - binary_accuracy: 0.8873 - val_loss: 0.3711 - val_binary_accuracy: 0.8386
# Epoch 35/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2636 - binary_accuracy: 0.8891 - val_loss: 0.4040 - val_binary_accuracy: 0.8214
# Epoch 36/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2587 - binary_accuracy: 0.8914 - val_loss: 0.4005 - val_binary_accuracy: 0.8300
# Epoch 37/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2544 - binary_accuracy: 0.8923 - val_loss: 0.3760 - val_binary_accuracy: 0.8330
# Epoch 38/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2497 - binary_accuracy: 0.8947 - val_loss: 0.3878 - val_binary_accuracy: 0.8300
# Epoch 39/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2425 - binary_accuracy: 0.8989 - val_loss: 0.3954 - val_binary_accuracy: 0.8303
# Epoch 40/40
# 10950/10950 [==============================] - 28s 3ms/step - loss: 0.2389 - binary_accuracy: 0.8996 - val_loss: 0.4120 - val_binary_accuracy: 0.8281

# %%
plot_history(hist)
# Out:
# History keys: ['loss', 'val_binary_accuracy', 'val_loss', 'binary_accuracy']

# %%
plot_metrics(metrics)

# %%
predictions = model.predict(eval_x)
predictions[predictions>=0.5] = 1
predictions[predictions<0.5] = 0

from sklearn.metrics import hamming_loss
print("Hamming Loss:",hamming_loss(eval_y,predictions))

# a diferença entre o ground truth e predições será toda 0 quando os dois forem iguais
## Então buscamos desses não dão tudo 0 e tiramos o inverso disso
predicted_diference = eval_y-predictions
correcly_predicted = (np.where(~(predicted_diference).any(axis=1))[0])
print("Exact match:",correcly_predicted.shape[0])
print("Accuracy Exact match:", float(correcly_predicted.shape[0])/eval_y.shape[0])
# Out:
# ('Hamming Loss:', 0.17185821697099893)
# ('Total of correcly predicted:', 168)
# ('Accuracy of correclty predicted:', 0.3157894736842105)

# %% [markdown]
# ## Acertos e erros por label
# Tipo alguns que acertaram quase todos ou todos

# %%
labels = ["Wind","Thunder","Rain","Ocean","Fire","Explosion","Gunshot, gunfire"]
multilabel_confusion_matrix(eval_y,predictions,n_classes)
# Out:
# Multilabel Confusion Matrix
#   TP,   FP,     TN,     FN,
# 0 112	80	279	61
# 1 12	16	463	41
# 2 36	33	407	56
# 3 49	112	358	13
# 4 28	12	460	32
# 5 22	30	447	33
# 6 74	33	337	88
# Σ 333	316	2751	324
#
# F1 Score: 0.474009
# Recall: 0.482700
# Precision: 0.521808
# Hamming Loss: 0.171858

# %%
model.save('modelos_salvos/2000video_cnn.h5') 

np.save('modelos_salvos/2000video_metrics.npy', metrics.custom_metrics)
np.save('modelos_salvos/2000video_history.npy', hist.history)
